# %%
# Since this notebook is supposed to run on CPU-based environments, we list the CPU configurations

# !lscpu
# Out:
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              36
# On-line CPU(s) list: 0-35
# Thread(s) per core:  1
# Core(s) per socket:  18
# Socket(s):           2
# NUMA node(s):        2
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               79
# Model name:          Intel(R) Xeon(R) CPU E5-2695 v4 @ 2.10GHz
# Stepping:            1
# CPU MHz:             3300.000
# CPU max MHz:         3300.0000
# CPU min MHz:         1200.0000
# BogoMIPS:            4190.29
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            46080K
# NUMA node0 CPU(s):   0-17
# NUMA node1 CPU(s):   18-35
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm constant_tsc arch_perfmon pebs bts rep_good nopl xtopology nonstop_tsc cpuid aperfmperf pni pclmulqdq dtes64 monitor ds_cpl smx est tm2 ssse3 sdbg fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave avx f16c rdrand lahf_lm abm 3dnowprefetch cpuid_fault epb cat_l3 cdp_l3 invpcid_single pti intel_ppin ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm rdt_a rdseed adx smap intel_pt xsaveopt cqm_llc cqm_occup_llc cqm_mbm_total cqm_mbm_local dtherm ida arat pln pts flush_l1d

# %%
# Verify number of CPU cores available to spawn different jobs

import multiprocessing

cpu_cores = multiprocessing.cpu_count()
print(f'Number of cpu cores available is {cpu_cores}.')
# Out:
# Number of cpu cores available is 36.

# %%
# Set up the basic prerequisites

import os
import numpy as np
import pandas as pd

base_dir = '/lcrc/project/NEXTGENOPT/NREL_COMSTOCK_DATA'
versionID = 32

metadata = pd.read_parquet(base_dir+f'/upgrade{versionID}.parquet') 

# split into different meradatas depending upon which state it is from

metadata_grouped = metadata.groupby('in.state')
m_states = [group for _,group in metadata_grouped]

# split the metadata into list-of-lists which can be parallelized 

def chunk_list(lst, m):
    # function to chunk list almost equally into list-of-lists
    n = len(lst)
    avg = n / m
    out = []
    last = 0.0

    while last < n:
        out.append(lst[int(last):int(last + avg)])
        last += avg

    return out

m_states_parallel = chunk_list(m_states,cpu_cores)
# Out:
# /var/tmp/pbs.1843.bebopmgt5/ipykernel_399334/3930401722.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   metadata_grouped = metadata.groupby('in.state')

# %%
# In this block, define the basic function which will allow parallelization

power_consumption_feature_name = 'out.electricity.total.energy_consumption'

def df_col_idx(idx,colname,df):
    
    # index a dataframe column as if it were a list
    # note: use SPARINGLY, can be expensive
    
    dfcol = df[colname].tolist()
    return dfcol[idx]

def parallel_function(m_states_superlist):
    
    for mdata in m_states_superlist:
        
        state_name = df_col_idx(0,'in.state',mdata)
        print(f'Executing state {state_name} on process PID {os.getpid()}.')
        
        # load all data
        bldg_ID = mdata.index.tolist()
        county_ID = mdata['in.nhgis_county_gisjoin'].tolist()
        
        corrs, retained_idx, avg_power = [], [], []
        ftr_name, ftr_name_recorded = [], False
        
        for bid,co_id in zip(bldg_ID,county_ID):
            
            if not (
                    os.path.exists(base_dir+f'/{state_name}/{bid}-{versionID}.parquet') 
                    and 
                    os.path.exists(base_dir+f'/weather/{co_id}_2018.csv')):
                print(f'Could not find building ID {bid} and/or weather data {co_id} for for state {state_name}. Continuing.')
                continue
            
            
            b_df = pd.read_parquet(base_dir+f'/{state_name}/{bid}-{versionID}.parquet')
            w_df = pd.read_csv(base_dir+f'/weather/{co_id}_2018.csv')
            retained_idx.append(bid)
            float_columns = b_df.select_dtypes(include=['float', 'float16', 'float32', 'float64']).columns.tolist()
            other_cols = [colname for colname in float_columns if colname != power_consumption_feature_name]
            weather_cols = w_df.select_dtypes(include=['float', 'float16', 'float32', 'float64']).columns.tolist()
            
            power_consumption = b_df[power_consumption_feature_name].to_numpy()
            avg_power.append(power_consumption.mean())
            
            other_features_corr = []
            
            # building specific features
            for ftr in other_cols:
                
                other_feature = b_df[ftr].to_numpy()
                with np.errstate(invalid='ignore'):
                    other_features_corr.append(np.corrcoef(power_consumption,other_feature)[0,1])
                if not ftr_name_recorded:
                    ftr_name.append(ftr)
                    
            # weather features
            for ftr in weather_cols:
                
                other_feature = np.repeat(w_df[ftr].to_numpy(),4)
                with np.errstate(invalid='ignore'):
                    other_features_corr.append(np.corrcoef(power_consumption,other_feature)[0,1])
                if not ftr_name_recorded:
                    ftr_name.append(ftr)
                    
            ftr_name_recorded = True
            
            corrs.append(other_features_corr)
            
        # take average of all correlations across buildings
        
        corrs_all_bldg = np.array(corrs).mean(axis=0)
        
        # descending order sort
        idx_desc = np.argsort(corrs_all_bldg)[::-1]
        feature_name_desc = [ftr_name[i] for i in idx_desc]
        corrs_desc = corrs_all_bldg[idx_desc]
        
        # before we print the results, we are also going to do a static features analysis
        # columns in the metadata which are numeric in value
        float_columns = mdata.select_dtypes(include=['float', 'float16', 'float32', 'float64']).columns.tolist()
        avg_power = np.array(avg_power)
        static_corr = []
        
        for ftr in float_columns:
            ftr_vec = mdata.loc[retained_idx, ftr].to_numpy()
            with np.errstate(invalid='ignore'):
                static_corr.append(np.corrcoef(avg_power,ftr_vec)[0,1])
        static_corr = np.array(static_corr)
        
        # organize static features in descending order
        # descending order sort
        idx_static_desc = np.argsort(static_corr)[::-1]
        feature_name_static_desc = [float_columns[i] for i in idx_static_desc]
        corrs_static_desc = static_corr[idx_static_desc]
        
        # print correlations of dynamic features
        print(f'For state {state_name}, the dynamic feature correlation to the building power consumption, average across all buildings, are as follows.:')
        for fname,fval in zip(feature_name_desc,corrs_desc):
            if np.isnan(fval):
                continue
            print(f"{fname}:\t {fval}")
            
        # print correlations of static features
        print(f'For state {state_name}, the static feature correlation to the building power consumption, average across all buildings, are as follows.:')
        for fname,fval in zip(feature_name_static_desc,corrs_static_desc):
            if np.isnan(fval):
                continue
            print(f"{fname}:\t {fval}")
            
    return 0

# %%
# In this block, we achieve parallelization

from concurrent.futures import ProcessPoolExecutor

with ProcessPoolExecutor(max_workers=cpu_cores) as executor:
    results = list(executor.map(parallel_function, m_states_parallel))
# Out:
# Executing state AK on process PID 414154.
# Executing state AL on process PID 414153.
# Executing state AZ on process PID 414155.
# Executing state DE on process PID 414158.Executing state DC on process PID 414159.
#
# Executing state CO on process PID 414157.
# Executing state CA on process PID 414156.
# Executing state HI on process PID 414161.
# Executing state ID on process PID 414162.Executing state FL on process PID 414160.
#
# Executing state IN on process PID 414163.
# Executing state IA on process PID 414164.
# Executing state KS on process PID 414165.
# Executing state LA on process PID 414166.
# Executing state ME on process PID 414167.
# Executing state MA on process PID 414168.
# Executing state MI on process PID 414169.
# Executing state MS on process PID 414170.
# Executing state MT on process PID 414172.
# Executing state NV on process PID 414173.Executing state MO on process PID 414171.
#
# Executing state NH on process PID 414174.
# Executing state NM on process PID 414175.
# Executing state ND on process PID 414177.Executing state NY on process PID 414176.
#
# Executing state OH on process PID 414178.
# Executing state OK on process PID 414179.
# Executing state PA on process PID 414180.
# Executing state SD on process PID 414182.
# Executing state RI on process PID 414181.
# Executing state TN on process PID 414183.
# Executing state TX on process PID 414184.
# Executing state VT on process PID 414185.
# Executing state VA on process PID 414186.
# Executing state WV on process PID 414187.
# Executing state WI on process PID 414188.
# Could not find building ID 5486 and/or weather data G0202750 for for state AK. Continuing.
# Could not find building ID 5509 and/or weather data G0202900 for for state AK. Continuing.
# Could not find building ID 5742 and/or weather data G0202700 for for state AK. Continuing.
# Could not find building ID 5611 and/or weather data G0202900 for for state AK. Continuing.
# For state VT, the dynamic feature correlation to the building power consumption, average across all buildings, are as follows.:
# out.electricity.cooling.energy_consumption_intensity:	 nan
# out.natural_gas.water_systems.energy_consumption:	 nan
# out.district_heating.water_systems.energy_consumption_intensity:	 nan
# out.district_heating.heating.energy_consumption_intensity:	 nan
# out.district_cooling.cooling.energy_consumption_intensity:	 nan
# out.other_fuel.water_systems.energy_consumption:	 nan
# out.other_fuel.total.energy_consumption:	 nan
# out.other_fuel.heating.energy_consumption:	 nan
# out.other_fuel.cooling.energy_consumption:	 nan
# out.district_heating.cooling.energy_consumption:	 nan
# out.natural_gas.total.energy_consumption:	 nan
# out.district_heating.total.energy_consumption:	 nan
# out.district_cooling.total.energy_consumption:	 nan
# out.natural_gas.interior_equipment.energy_consumption:	 nan
# out.electricity.heat_recovery.energy_consumption_intensity:	 nan
# out.natural_gas.heating.energy_consumption:	 nan
# out.electricity.water_systems.energy_consumption:	 nan
# out.electricity.refrigeration.energy_consumption:	 nan
# out.electricity.pumps.energy_consumption:	 nan
# out.electricity.heating.energy_consumption:	 nan
# out.electricity.heat_rejection.energy_consumption:	 nan
# out.electricity.heat_recovery.energy_consumption:	 nan
# out.electricity.fans.energy_consumption:	 nan
# out.electricity.cooling.energy_consumption:	 nan
# out.district_heating.water_systems.energy_consumption:	 nan
# out.district_heating.heating.energy_consumption:	 nan
# out.electricity.fans.energy_consumption_intensity:	 nan
# out.district_cooling.cooling.energy_consumption:	 nan
# out.electricity.heat_rejection.energy_consumption_intensity:	 nan
# out.natural_gas.interior_equipment.energy_consumption_intensity:	 nan
# out.other_fuel.water_systems.energy_consumption_intensity:	 nan
# out.other_fuel.total.energy_consumption_intensity:	 nan
# out.other_fuel.heating.energy_consumption_intensity:	 nan
# out.other_fuel.cooling.energy_consumption_intensity:	 nan
# out.district_heating.cooling.energy_consumption_intensity:	 nan
# out.district_heating.total.energy_consumption_intensity:	 nan
# out.district_cooling.total.energy_consumption_intensity:	 nan
# out.natural_gas.water_systems.energy_consumption_intensity:	 nan
# out.natural_gas.total.energy_consumption_intensity:	 nan
# out.natural_gas.heating.energy_consumption_intensity:	 nan
# out.electricity.heating.energy_consumption_intensity:	 nan
# out.electricity.refrigeration.energy_consumption_intensity:	 nan
# out.electricity.pumps.energy_consumption_intensity:	 nan
# out.electricity.water_systems.energy_consumption_intensity:	 nan
# out.electricity.total.energy_consumption_intensity:	 1.0
# out.site_energy.total.energy_consumption:	 0.7367954927823778
# out.site_energy.total.energy_consumption_intensity:	 0.7367954927823777
# out.electricity.interior_lighting.energy_consumption:	 0.5414090892914402
# out.electricity.interior_lighting.energy_consumption_intensity:	 0.5414090892914396
# out.electricity.interior_equipment.energy_consumption_intensity:	 0.5301247732926992
# out.electricity.interior_equipment.energy_consumption:	 0.5301247732926992
# Global Horizontal Radiation [W/m2]:	 0.26426090179955386
# Diffuse Horizontal Radiation [W/m2]:	 0.23885887405307912
# Direct Normal Radiation [W/m2]:	 0.23480188134457178
# Wind Speed [m/s]:	 0.1280713956003208
# Wind Direction [Deg]:	 0.09862740101233212
# Dry Bulb Temperature [°C]:	 -0.12737134585527676
# Relative Humidity [%]:	 -0.18083211399219903
# out.electricity.exterior_lighting.energy_consumption_intensity:	 -0.23607645830359356
# out.electricity.exterior_lighting.energy_consumption:	 -0.23607645830359356
# For state VT, the static feature correlation to the building power consumption, average across all buildings, are as follows.:
# out.params.heat_pump_cooling_total_electric..j:	 nan
# out.params.hp_water_heater_backup_electric..j:	 nan
# out.params.hp_water_heater_90_plus_capacity..w:	 nan
# out.params.hp_water_heater_90_plus_gal_cop..cop:	 nan
# out.params.hp_water_heater_90_plus_gal_count:	 nan
# out.utility_bills.fuel_oil_bill_intensity..usd_per_ft2:	 nan
# out.utility_bills.natural_gas_bill..usd:	 nan
# out.params.hp_water_heater_90_plus_gal_total_volume..gal:	 nan
# out.params.hp_water_heater_capacity..w:	 nan
# out.params.hp_water_heater_65_to_90_gal_count:	 nan
# calc.weighted.district_heating.cooling.energy_consumption..tbtu:	 nan
# out.params.hp_water_heater_cop..cop:	 nan
# out.params.hp_water_heater_count:	 nan
# out.params.hp_water_heater_heat_pump_electric..j:	 nan
# out.params.hp_water_heater_heat_pump_output..j:	 nan
# out.params.hp_water_heater_tank_output..j:	 nan
# out.params.hp_water_heater_65_to_90_gal_total_volume..gal:	 nan
# out.params.hp_water_heater_65_to_90_gal_cop..cop:	 nan
# out.params.hp_water_heater_total_output..j:	 nan
# out.params.hp_water_heater_0_to_40_gal_capacity..w:	 nan
# calc.weighted.enduse_group.district_heating.interior_equipment.energy_consumption..tbtu:	 nan
# out.params.heat_pump_cooling_source_inlet_temp..c:	 nan
# calc.percent_savings.district_heating.cooling.energy_consumption_intensity..percent:	 nan
# out.utility_bills.fuel_oil_bill..usd:	 nan
# out.params.heat_pump_cooling_total_load..j:	 nan
# out.utility_bills.propane_bill_intensity..usd_per_ft2:	 nan
# out.params.hp_water_heater_0_to_40_gal_cop..cop:	 nan
# out.params.hp_water_heater_65_to_90_gal_capacity..w:	 nan
# out.params.hp_water_heater_0_to_40_gal_count:	 nan
# out.params.hp_water_heater_0_to_40_gal_total_volume..gal:	 nan
# out.params.hp_water_heater_40_to_65_gal_capacity..w:	 nan
# out.params.hp_water_heater_40_to_65_gal_cop..cop:	 nan
# out.params.hp_water_heater_40_to_65_gal_count:	 nan
# For state HI, the dynamic feature correlation to the building power consumption, average across all buildings, are as follows.:out.params.hp_water_heater_40_to_65_gal_total_volume..gal:	 nan
# out.electricity.cooling.energy_consumption_intensity:	 nan
#
# out.natural_gas.water_systems.energy_consumption:	 nan
# out.district_heating.water_systems.energy_consumption_intensity:	 nan
# out.params.hp_water_heater_total_electric..j:	 nanout.district_heating.heating.energy_consumption_intensity:	 nan
#
# out.district_cooling.cooling.energy_consumption_intensity:	 nan
# out.other_fuel.water_systems.energy_consumption:	 nan
# out.other_fuel.total.energy_consumption:	 nan
# out.other_fuel.heating.energy_consumption:	 nan
# out.other_fuel.cooling.energy_consumption:	 nan
# out.district_heating.cooling.energy_consumption:	 nan
# out.natural_gas.total.energy_consumption:	 nan
# out.district_heating.total.energy_consumption:	 nan
# out.district_cooling.total.energy_consumption:	 nanout.params.hp_water_heater_total_volume..gal:	 nan
# out.natural_gas.interior_equipment.energy_consumption:	 nan
# out.electricity.heat_recovery.energy_consumption_intensity:	 nan
#
# out.params.heat_pump_cooling_capacity..kbtu_per_hr:	 nanout.natural_gas.heating.energy_consumption:	 nan
#
# calc.percent_savings.electricity.heating.energy_consumption..percent:	 nanout.electricity.water_systems.energy_consumption:	 nan
# out.electricity.refrigeration.energy_consumption:	 nan
# out.electricity.pumps.energy_consumption:	 nan
#
# out.params.vrf_heating_total_supplemental_load_electric..j:	 nanout.electricity.heating.energy_consumption:	 nan
# calc.percent_savings.electricity.interior_lighting.energy_consumption_intensity..percent:	 nan
# out.electricity.heat_rejection.energy_consumption:	 nan
# out.electricity.heat_recovery.energy_consumption:	 nan
# out.electricity.fans.energy_consumption:	 nan
#
# out.electricity.cooling.energy_consumption:	 nancalc.percent_savings.electricity.interior_lighting.energy_consumption..percent:	 nan
#
# calc.percent_savings.electricity.interior_equipment.energy_consumption_intensity..percent:	 nanout.district_heating.water_systems.energy_consumption:	 nan
# calc.percent_savings.electricity.interior_equipment.energy_consumption..percent:	 nan
# calc.percent_savings.electricity.heating.energy_consumption_intensity..percent:	 nan
#
# out.district_heating.heating.energy_consumption:	 nan
# out.params.vrf_heating_total_supplemental_load_gas..j:	 nanout.electricity.fans.energy_consumption_intensity:	 nan
# out.district_cooling.cooling.energy_consumption:	 nan
#
# out.params.vrf_heating_total_supplemental_gas..j:	 nanout.electricity.heat_rejection.energy_consumption_intensity:	 nan
# calc.percent_savings.electricity.heat_recovery.energy_consumption_intensity..percent:	 nan
#
# out.natural_gas.interior_equipment.energy_consumption_intensity:	 nan
# out.other_fuel.water_systems.energy_consumption_intensity:	 nan
# out.other_fuel.total.energy_consumption_intensity:	 nancalc.percent_savings.electricity.heat_recovery.energy_consumption..percent:	 nan
#
# out.other_fuel.heating.energy_consumption_intensity:	 nancalc.percent_savings.electricity.exterior_lighting.energy_consumption_intensity..percent:	 nan
#
# out.other_fuel.cooling.energy_consumption_intensity:	 nancalc.percent_savings.electricity.exterior_lighting.energy_consumption..percent:	 nan
# out.district_heating.cooling.energy_consumption_intensity:	 nan
# out.utility_bills.natural_gas_bill_intensity..usd_per_ft2:	 nan
# calc.enduse_group.other_fuel.interior_equipment.energy_consumption..kwh:	 nan
#
# out.params.vrf_heating_total_supplemental_load..j:	 nanout.district_heating.total.energy_consumption_intensity:	 nan
#
# out.params.vrf_heating_total_supplemental_electric..j:	 nan
# out.district_cooling.total.energy_consumption_intensity:	 nancalc.percent_savings.other_fuel.interior_equipment.energy_consumption_intensity..percent:	 nan
# out.natural_gas.water_systems.energy_consumption_intensity:	 nan
# out.natural_gas.total.energy_consumption_intensity:	 nan
# out.natural_gas.heating.energy_consumption_intensity:	 nan
# out.params.hvac_count_heat_pumps_heating_300_to_2500_kbtuh:	 nan
# out.electricity.heating.energy_consumption_intensity:	 nan
#
# calc.percent_savings.other_fuel.interior_equipment.energy_consumption..percent:	 nanout.electricity.refrigeration.energy_consumption_intensity:	 nan
#
# out.params.hp_water_heater_unmet_heat_transfer_demand..j:	 nanout.electricity.pumps.energy_consumption_intensity:	 nan
#
# out.params.hvac_count_heat_pumps_cooling:	 nanout.electricity.water_systems.energy_consumption_intensity:	 nan
# out.electricity.total.energy_consumption_intensity:	 1.0
# out.site_energy.total.energy_consumption:	 0.9929287221789541
#
# calc.percent_savings.other_fuel.cooling.energy_consumption_intensity..percent:	 nanout.site_energy.total.energy_consumption_intensity:	 0.9929287221789539
#
# calc.percent_savings.other_fuel.cooling.energy_consumption..percent:	 nan
# out.electricity.interior_lighting.energy_consumption_intensity:	 0.8185347499745393
# out.params.hvac_count_heat_pumps_heating_2500_plus_kbtuh:	 nan
# out.electricity.interior_lighting.energy_consumption:	 0.8185347499745392out.params.internal_mass_area_ratio:	 nan
#
# out.params.vrf_heating_fraction_supplemental:	 nanout.electricity.interior_equipment.energy_consumption:	 0.7940319104706086
#
# out.utility_bills.propane_bill..usd:	 nanout.electricity.interior_equipment.energy_consumption_intensity:	 0.7940319104706085
# calc.percent_savings.natural_gas.interior_equipment.energy_consumption_intensity..percent:	 nan
#
# Dry Bulb Temperature [°C]:	 0.27182024136687893calc.percent_savings.natural_gas.interior_equipment.energy_consumption..percent:	 nan
#
# Wind Speed [m/s]:	 0.2156462328425036
# out.utility_bills.natural_gas_energy_rate..usd_per_kwh:	 nanGlobal Horizontal Radiation [W/m2]:	 0.046375245392051186
#
# calc.percent_savings.natural_gas.cooling.energy_consumption_intensity..percent:	 nanDirect Normal Radiation [W/m2]:	 0.04610157475012363
# calc.percent_savings.natural_gas.cooling.energy_consumption..percent:	 nan
#
# Diffuse Horizontal Radiation [W/m2]:	 0.024046756420919344
# out.params.heat_pump_cooling_load_weight_cop..cop:	 nan
# Wind Direction [Deg]:	 -0.04513542323248915calc.percent_savings.district_heating.cooling.energy_consumption..percent:	 nan
#
# out.params.heat_pump_cooling_cap_weight_cop..cop:	 nanRelative Humidity [%]:	 -0.18671337839692947
#
# out.electricity.interior_lighting.energy_savings:	 nanout.electricity.exterior_lighting.energy_consumption_intensity:	 -0.5212491830586939
#
# out.electricity.exterior_lighting.energy_consumption:	 -0.5212491830586939out.emissions.electricity.interior_equipment_fuel_oil_ghg_emissions..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment_propane_ghg_emissions..co2e_kg:	 nan
# out.params.dx_cooling_design_seer_30_to_65_kbtuh..seer:	 nan
# For state HI, the static feature correlation to the building power consumption, average across all buildings, are as follows.:
#
# calc.weighted.other_fuel.cooling.energy_consumption..tbtu:	 nan
# out.emissions.electricity.water_systems.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nan
# out.params.dx_cooling_design_seer_0_to_30_kbtuh..seer:	 nan
# out.params.heat_pump_cooling_total_electric..j:	 nan
# out.params.fluid_hx_transfer_energy..j:	 nan
# out.emissions.electricity.heating.aer_95_decarb_by_2050_from_2023..co2e_kg:	 nan
# out.emissions.electricity.heating.aer_95_decarb_by_2035_from_2023..co2e_kg:	 nan
# out.params.ghx_borehole_depth..ft:	 nan
# out.params.ghx_flow_rate..ft3_per_min:	 nan
# out.params.ghx_num_boreholes:	 nan
# out.params.hdd50f:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# out.params.heat_pump_cooling_average_cop..cop:	 nan
# out.params.heat_pump_cooling_cap_weight_cop..cop:	 nan
# out.params.heat_pump_cooling_capacity..kbtu_per_hr:	 nan
# out.params.heat_pump_cooling_load_weight_cop..cop:	 nan
# out.params.heat_pump_cooling_source_inlet_temp..c:	 nan
# out.params.heat_pump_cooling_total_load..j:	 nancalc.weighted.other_fuel.interior_equipment.energy_consumption..tbtu:	 nan
#
# out.params.hours_below_50f..hr:	 nanout.params.heat_pump_cooling_average_cop..cop:	 nan
#
# out.params.dx_cooling_design_ieer_65_to_135_kbtuh..ieer:	 nanout.emissions.electricity.exterior_lighting.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
#
# out.params.dx_cooling_design_ieer_240_to_760_kbtuh..ieer:	 nanout.emissions.electricity.exterior_lighting.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
#
# calc.weighted.savings.district_heating.cooling.energy_consumption..tbtu:	 nanout.emissions.electricity.exterior_lighting.lrmer_mid_case_15_2023_start..co2e_kg:	 nan
#
# out.params.dx_cooling_design_ieer_135_to_240_kbtuh..ieer:	 nanout.emissions.electricity.exterior_lighting.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
#
# out.params.dx_cooling_design_eer_760_plus_kbtuh..eer:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nanout.params.dx_cooling_design_eer_65_to_135_kbtuh..eer:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nan
# calc.weighted.savings.electricity.exterior_lighting.energy_consumption..tbtu:	 nan
# calc.weighted.natural_gas.cooling.energy_consumption..tbtu:	 nan
# out.params.dx_cooling_design_eer_240_to_760_kbtuh..eer:	 nan
# out.electricity.interior_equipment.energy_savings:	 nan
# out.params.dx_cooling_design_eer_135_to_240_kbtuh..eer:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nan
# out.params.hours_above_65f..hr:	 nan
#
# out.params.booster_water_heater_gas..j:	 nan
# calc.weighted.savings.electricity.interior_equipment.energy_consumption..tbtu:	 nan
# calc.weighted.savings.electricity.interior_lighting.energy_consumption..tbtu:	 nan
# out.electricity.exterior_lighting.energy_savings:	 nanout.params.hours_below_0f..hr:	 nan
#
# out.params.fluid_hx_supply_outlet_temp..c:	 nan
# calc.weighted.savings.natural_gas.cooling.energy_consumption..tbtu:	 nan
# out.params.fluid_hx_supply_inlet_temp..c:	 nan
# out.params.fluid_hx_demand_outlet_temp..c:	 nan
# calc.weighted.savings.natural_gas.interior_equipment.energy_consumption..tbtu:	 nanout.params.fluid_hx_demand_inlet_temp..c:	 nan
#
# out.emissions.electricity.interior_equipment.aer_95_decarb_by_2050_from_2023..co2e_kg:	 nanout.district_heating.cooling.energy_savings:	 nan
#
# calc.weighted.savings.other_fuel.cooling.energy_consumption..tbtu:	 nan
# out.emissions.electricity.interior_equipment.aer_95_decarb_by_2035_from_2023..co2e_kg:	 nanout.district_heating.cooling.energy_consumption:	 nan
# out.emissions.electricity.heating.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# calc.weighted.savings.other_fuel.interior_equipment.energy_consumption..tbtu:	 nan
# out.emissions.electricity.heating.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
#
# out.params.dx_heating_supplemental_capacity_gas..kbtu_per_hr:	 nanout.params.dx_heating_fraction_electric_defrost:	 nan
# out.params.dx_cooling_design_ieer_760_plus_kbtuh..ieer:	 nan
#
# out.emissions.electricity.heating.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.heating.lrmer_mid_case_15_2023_start..co2e_kg:	 nanout.params.dx_heating_total_supplemental_gas..j:	 nan
# out.params.dx_heating_hours_below_minus_20f..hr:	 nan
# out.district_heating.cooling.energy_consumption_intensity:	 nan
#
# out.other_fuel.interior_equipment.energy_savings_intensity:	 nan
# out.params.ghx_num_boreholes:	 nan
# out.params.ghx_flow_rate..ft3_per_min:	 nan
# out.other_fuel.interior_equipment.energy_consumption_intensity:	 nan
# out.other_fuel.cooling.energy_savings_intensity:	 nan
# out.other_fuel.cooling.energy_consumption_intensity:	 nanout.params.dx_heating_ratio_defrost:	 nan
# out.natural_gas.interior_equipment.energy_savings_intensity:	 nan
#
# out.natural_gas.cooling.energy_savings_intensity:	 nanout.emissions.electricity.heating.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
#
# out.emissions.electricity.heating.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nan
# out.params.dx_heating_supplemental_capacity_gas..kbtu_per_hr:	 nan
# out.emissions.electricity.heating.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nanout.natural_gas.cooling.energy_consumption_intensity:	 nan
# out.emissions.electricity.heating.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
#
# out.electricity.interior_lighting.energy_savings_intensity:	 nan
# out.params.dx_heating_total_supplemental_load_gas..j:	 nan
# out.electricity.exterior_lighting.energy_savings_intensity:	 nan
# out.district_heating.cooling.energy_savings_intensity:	 nanout.emissions.electricity.heating.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.electricity.interior_equipment.energy_savings_intensity:	 nan
#
# out.emissions.electricity.heating.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nanout.params.ghx_borehole_depth..ft:	 nan
#
# out.params.dx_heating_total_supplemental_gas..j:	 nanout.other_fuel.interior_equipment.energy_savings:	 nan
#
# out.emissions.electricity.heating.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nanout.params.fluid_hx_demand_inlet_temp..c:	 nan
#
# out.emissions.electricity.heating.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nan
# out.params.dx_heating_total_supplemental_load_gas..j:	 nan
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nanout.natural_gas.cooling.energy_savings:	 nan
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
#
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nanout.params.fluid_hx_demand_outlet_temp..c:	 nan
#
# out.emissions.electricity.heating.aer_mid_case_from_2023..co2e_kg:	 nan
# out.params.fluid_hx_supply_inlet_temp..c:	 nan
# out.emissions.electricity.heating.aer_low_re_cost_from_2023..co2e_kg:	 nanout.natural_gas.interior_equipment.energy_savings:	 nan
# out.other_fuel.cooling.energy_savings:	 nan
# out.other_fuel.cooling.energy_consumption:	 nan
# calc.weighted.enduse_group.other_fuel.interior_equipment.emissions..co2e_mmt:	 nan
#
# out.emissions.electricity.heating.aer_high_re_cost_from_2023..co2e_kg:	 nancalc.weighted.enduse_group.other_fuel.interior_equipment.energy_consumption..tbtu:	 nan
#
# out.params.fluid_hx_transfer_energy..j:	 nan
# out.params.hours_below_17f..hr:	 nanout.params.fluid_hx_supply_outlet_temp..c:	 nan
# out.params.hours_below_5f..hr:	 nan
# out.emissions.electricity.egrid_2018_subregion..co2e_kg:	 1.0
# out.emissions.electricity.egrid_2019_subregion..co2e_kg:	 1.0
# out.emissions.electricity.egrid_2021_subregion..co2e_kg:	 1.0
# out.emissions.electricity.egrid_2020_subregion..co2e_kg:	 0.9999999999999999
# out.electricity.total.energy_consumption:	 0.9999999999987517
# out.emissions.electricity.lrmer_mid_case_15_2025_start..co2e_kg:	 0.9998071502061121
# out.emissions.electricity.lrmer_mid_case_25_2025_start..co2e_kg:	 0.9997747620262354
# out.emissions.electricity.lrmer_high_re_cost_15_2023_start..co2e_kg:	 0.9997253511856405
# out.emissions.electricity.aer_high_re_cost_from_2023..co2e_kg:	 0.9996475529550386
# out.emissions.electricity.aer_mid_case_from_2023..co2e_kg:	 0.9995501905615813
# out.emissions.electricity.aer_95_decarb_by_2050_from_2023..co2e_kg:	 0.9995471990050147
# out.emissions.electricity.interior_equipment.aer_low_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.aer_low_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.aer_high_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.aer_95_decarb_by_2050_from_2023..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.aer_95_decarb_by_2035_from_2023..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.aer_95_decarb_by_2035_from_2023..co2e_kg:	 0.9995471990050147
# out.emissions.electricity.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 0.9995263832382849
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nan
# out.params.hvac_count_heat_pumps_cooling:	 nan
# out.emissions.electricity.lrmer_high_re_cost_30_2023_start..co2e_kg:	 0.9995260460908244
# out.emissions.electricity.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 0.9995087620725118
# out.emissions.electricity.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 0.9994953603846806
# out.emissions.electricity.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 0.9994952984736475
# out.emissions.electricity.lrmer_mid_case_15_2023_start..co2e_kg:	 0.9994828510141871
# out.emissions.electricity.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 0.9994651444429237
# out.emissions.electricity.lrmer_low_re_cost_25_2025_start..co2e_kg:	 0.9993824418717567
# out.emissions.electricity.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 0.9993542735483331
# out.emissions.electricity.aer_low_re_cost_from_2023..co2e_kg:	 0.9993519009598718
# out.emissions.electricity.lrmer_low_re_cost_15_2023_start..co2e_kg:	 0.9992461547591632
#
# out.emissions.electricity.lrmer_mid_case_30_2023_start..co2e_kg:	 0.9991445531342491
# out.emissions.electricity.lrmer_low_re_cost_30_2023_start..co2e_kg:	 0.999076178048756
# out.emissions.electricity.lrmer_low_re_cost_15_2025_start..co2e_kg:	 0.9990654675563668
# out.utility_bills.electricity_bill_min..usd:	 0.9972697368536964out.params.hvac_count_heat_pumps_heating_2500_plus_kbtuh:	 nan
#
# out.utility_bills.electricity_bill_mean..usd:	 0.9960907690867256
# out.utility_bills.electricity_bill_median..usd:	 0.9949020684872405
# out.electricity.total.nov.energy_consumption..kwh:	 0.9934316624651905
# out.utility_bills.electricity_bill_max..usd:	 0.9922863467493167
# out.electricity.total.apr.energy_consumption..kwh:	 0.9920493205183286
# out.electricity.total.mar.energy_consumption..kwh:	 0.9917319538897804
# out.electricity.total.oct.energy_consumption..kwh:	 0.9907304934471116
# out.qoi.q1_daily_peak_apr..kw:	 0.9860530799333964
# out.electricity.total.feb.energy_consumption..kwh:	 0.9841413603379026
# out.qoi.q1_daily_peak_oct..kw:	 0.9834344071153431
# out.params.hvac_count_heat_pumps_heating_300_to_2500_kbtuh:	 nanout.qoi.median_daily_peak_oct..kw:	 0.9819523292895752
#
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nan
# out.qoi.q3_daily_peak_oct..kw:	 0.9812772747748526out.params.internal_mass_area_ratio:	 nan
# out.emissions.electricity.enduse_group.hvac.aer_mid_case_from_2023..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.aer_low_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.aer_high_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.aer_mid_case_from_2023..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
# out.params.hp_water_heater_unmet_heat_transfer_demand..j:	 nan
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nan
# out.params.hp_water_heater_0_to_40_gal_capacity..w:	 nan
# out.params.hp_water_heater_0_to_40_gal_cop..cop:	 nan
# out.params.hp_water_heater_0_to_40_gal_count:	 nan
# out.params.hp_water_heater_0_to_40_gal_total_volume..gal:	 nan
# out.params.hp_water_heater_40_to_65_gal_capacity..w:	 nan
# out.params.hp_water_heater_40_to_65_gal_cop..cop:	 nan
# out.params.hp_water_heater_40_to_65_gal_count:	 nan
# out.params.hp_water_heater_40_to_65_gal_total_volume..gal:	 nan
# out.params.hp_water_heater_65_to_90_gal_capacity..w:	 nan
# out.params.hp_water_heater_65_to_90_gal_cop..cop:	 nan
# out.params.hp_water_heater_65_to_90_gal_count:	 nan
# out.params.hp_water_heater_65_to_90_gal_total_volume..gal:	 nan
# out.params.hp_water_heater_90_plus_capacity..w:	 nan
# out.params.hp_water_heater_90_plus_gal_cop..cop:	 nan
# out.params.hp_water_heater_90_plus_gal_count:	 nan
#
# out.electricity.total.sep.energy_consumption..kwh:	 0.9777781832507211
# out.electricity.total.may.energy_consumption..kwh:	 0.9772880632783082
# out.electricity.total.jun.energy_consumption..kwh:	 0.976631850243009
# out.electricity.total.aug.energy_consumption..kwh:	 0.9760535656355608out.params.hp_water_heater_90_plus_gal_total_volume..gal:	 nan
# out.electricity.total.jul.energy_consumption..kwh:	 0.9759902644297094
#
# out.qoi.median_daily_peak_apr..kw:	 0.9757987713192491
# out.qoi.q1_daily_peak_may..kw:	 0.9744336846716671
# out.qoi.maximum_daily_use_shoulder..kw:	 0.9734981111872185
# out.qoi.median_daily_peak_nov..kw:	 0.9720430536831383
# out.qoi.q1_daily_peak_jul..kw:	 0.9715658957233725
# out.qoi.median_daily_peak_sep..kw:	 0.9704789081868574
# out.qoi.q1_daily_peak_nov..kw:	 0.9698701330856694
# out.params.hp_water_heater_backup_electric..j:	 nanout.qoi.median_daily_peak_jun..kw:	 0.9698326417292121
# out.qoi.q1_daily_peak_sep..kw:	 0.9694686495453358
#
# out.qoi.median_daily_peak_aug..kw:	 0.9672239861781594
# out.params.hp_water_heater_capacity..w:	 nan
# out.qoi.q3_daily_peak_jun..kw:	 0.9664028488077502out.params.hp_water_heater_cop..cop:	 nan
# out.qoi.median_daily_peak_jul..kw:	 0.9660829384348296
#
# out.params.hp_water_heater_count:	 nan
# out.params.hp_water_heater_heat_pump_electric..j:	 nan
# out.params.hp_water_heater_heat_pump_output..j:	 nan
# out.params.hp_water_heater_tank_output..j:	 nan
# out.params.hp_water_heater_total_electric..j:	 nan
# out.electricity.total.dec.energy_consumption..kwh:	 0.9653176002797217out.params.hp_water_heater_total_output..j:	 nan
#
# out.qoi.q1_daily_peak_feb..kw:	 0.9651194926577287out.params.hp_water_heater_total_volume..gal:	 nan
#
# out.qoi.maximum_daily_use_summer..kw:	 0.9650183075674079out.emissions.electricity.interior_equipment.aer_high_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.aer_mid_case_from_2023..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.aer_95_decarb_by_2035_from_2023..co2e_kg:	 nan
# out.emissions.fuel_oil.enduse_group.hvac..co2e_kg:	 nan
#
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nanout.qoi.median_daily_peak_may..kw:	 0.9635619953806768
#
# out.qoi.maximum_daily_use_winter..kw:	 0.9630875206526706out.emissions.electricity.water_systems.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nan
# out.qoi.q1_daily_peak_aug..kw:	 0.9616126329575213
# out.qoi.q3_daily_peak_jul..kw:	 0.9613221602567958
# out.qoi.minimum_daily_peak_mar..kw:	 0.9607898333237875
# out.qoi.median_daily_peak_mar..kw:	 0.9604533439912586
# out.qoi.q3_daily_peak_apr..kw:	 0.9599367693978205
# out.qoi.q1_daily_peak_mar..kw:	 0.9596878682708044
# out.qoi.minimum_daily_peak_feb..kw:	 0.9596538081377773
# out.emissions.electricity.water_systems.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_mid_case_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_mid_case_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# out.emissions.fuel_oil..co2e_kg:	 nan
# out.emissions.fuel_oil.heating..co2e_kg:	 nan
# out.utility_bills.natural_gas_bill..usd:	 nan
# out.emissions.fuel_oil.water_systems..co2e_kg:	 nan
# out.emissions.electricity.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nan
# out.qoi.q1_daily_peak_jun..kw:	 0.9595245219588655
# out.qoi.q3_daily_peak_aug..kw:	 0.9594618415347883
# out.emissions.electricity.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.propane.enduse_group.hvac..co2e_kg:	 nan
# out.emissions.propane.heating..co2e_kg:	 nan
# out.emissions.electricity.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nan
# out.utility_bills.electricity_bill_number_of_rates..usd:	 nan
# out.emissions.electricity.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nan
# out.utility_bills.fuel_oil_bill..usd:	 nan
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_mid_case_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.water_systems.aer_95_decarb_by_2035_from_2023..co2e_kg:	 nan
# out.emissions.electricity.water_systems.aer_95_decarb_by_2050_from_2023..co2e_kg:	 nan
# out.emissions.electricity.water_systems.aer_high_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.water_systems.aer_low_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.water_systems.aer_mid_case_from_2023..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.aer_mid_case_from_2023..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.aer_low_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.aer_high_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.aer_95_decarb_by_2050_from_2023..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.aer_95_decarb_by_2035_from_2023..co2e_kg:	 nan
# out.emissions.electricity.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
# out.utility_bills.fuel_oil_bill_intensity..usd_per_ft2:	 nan
# out.utility_bills.natural_gas_bill_intensity..usd_per_ft2:	 nan
# out.params.dx_heating_defrost_energy..kbtu:	 nan
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# out.params.booster_water_heater_gas..j:	 nan
# out.emissions.electricity.interior_equipment.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
# out.params.cdd50f:	 nan
# out.emissions.electricity.interior_equipment.lrmer_mid_case_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nan
#
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.utility_bills.natural_gas_energy_rate..usd_per_kwh:	 nan
# out.params.dx_cooling_design_eer_135_to_240_kbtuh..eer:	 nan
# out.params.dx_cooling_design_eer_240_to_760_kbtuh..eer:	 nan
# out.params.dx_cooling_design_eer_65_to_135_kbtuh..eer:	 nan
# out.params.dx_cooling_design_eer_760_plus_kbtuh..eer:	 nan
# out.params.dx_cooling_design_ieer_135_to_240_kbtuh..ieer:	 nan
# out.params.dx_cooling_design_ieer_240_to_760_kbtuh..ieer:	 nan
# out.params.dx_cooling_design_ieer_65_to_135_kbtuh..ieer:	 nan
# out.params.dx_cooling_design_ieer_760_plus_kbtuh..ieer:	 nan
# out.params.dx_cooling_design_seer_0_to_30_kbtuh..seer:	 nan
# out.params.dx_cooling_design_seer_30_to_65_kbtuh..seer:	 nan
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nan
# out.params.boiler_other_fuel..j:	 nan
# out.emissions.electricity.interior_equipment_fuel_oil_ghg_emissions..co2e_kg:	 nan
# out.emissions.electricity.interior_equipment_propane_ghg_emissions..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.aer_95_decarb_by_2035_from_2023..co2e_kg:	 nan
# out.utility_bills.propane_bill..usd:	 nan
# out.utility_bills.propane_bill_intensity..usd_per_ft2:	 nan
# out.emissions.electricity.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_mid_case_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_mid_case_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_mid_case_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_mid_case_15_2023_start..co2e_kg:	 nan
# out.params.area_fraction_with_supply_air_temperature_reset:	 nan
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_25_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_high_re_cost_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_high_re_cost_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 nanout.qoi.q3_daily_peak_may..kw:	 0.9581452925181848
# out.qoi.minimum_daily_peak_jan..kw:	 0.9575764509786155
# out.qoi.q3_daily_peak_sep..kw:	 0.9575335096770029
# out.qoi.minimum_daily_peak_dec..kw:	 0.9550859276781543
# out.qoi.maximum_daily_peak_oct..kw:	 0.9549975786653501
# out.qoi.minimum_daily_peak_nov..kw:	 0.9547868704733917
# out.qoi.q1_daily_peak_jan..kw:	 0.9523766702625307
# out.qoi.median_daily_peak_feb..kw:	 0.9513843817714014
# out.electricity.total.jan.energy_consumption..kwh:	 0.9504029157693359
# out.qoi.minimum_daily_peak_apr..kw:	 0.9469939953257994
# out.qoi.minimum_daily_peak_jul..kw:	 0.9467224209911628
# out.qoi.maximum_daily_peak_jun..kw:	 0.9451343829234519
# out.qoi.minimum_daily_peak_aug..kw:	 0.9448716500102906
# out.qoi.maximum_daily_peak_jul..kw:	 0.943433097400742
# out.qoi.maximum_daily_peak_may..kw:	 0.9397813376537826
# out.qoi.q1_daily_peak_dec..kw:	 0.9391505904203413
# out.qoi.maximum_daily_peak_aug..kw:	 0.9389691882623352
# out.qoi.q3_daily_peak_nov..kw:	 0.9383161004904149
# out.qoi.minimum_daily_peak_sep..kw:	 0.9381209144689444
# out.qoi.minimum_daily_peak_jun..kw:	 0.932945810234659
# out.qoi.minimum_daily_peak_may..kw:	 0.931827175311179
# out.qoi.maximum_daily_peak_sep..kw:	 0.9314969870478275
# out.emissions.electricity.enduse_group.hvac.aer_low_re_cost_from_2023..co2e_kg:	 0.9305959980648529
# out.qoi.q3_daily_peak_mar..kw:	 0.9294994501368146
# out.emissions.electricity.enduse_group.hvac.aer_mid_case_from_2023..co2e_kg:	 0.9294459474497188
# out.emissions.electricity.enduse_group.hvac.aer_95_decarb_by_2035_from_2023..co2e_kg:	 0.9294302632969468
# out.emissions.electricity.enduse_group.hvac.aer_95_decarb_by_2050_from_2023..co2e_kg:	 0.9294302632969468
# out.emissions.electricity.enduse_group.hvac.aer_high_re_cost_from_2023..co2e_kg:	 0.9286268557940143
# out.qoi.minimum_daily_peak_oct..kw:	 0.9283626414543834
# out.qoi.maximum_daily_peak_apr..kw:	 0.9266797739323085
# out.emissions.electricity.enduse_group.hvac.lrmer_high_re_cost_30_2023_start..co2e_kg:	 0.9253156791926533
# out.emissions.electricity.enduse_group.hvac.lrmer_high_re_cost_15_2023_start..co2e_kg:	 0.9246239173565902
# calc.enduse_group.electricity.hvac.energy_consumption..kwh:	 0.9217338760162246
#
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.aer_mid_case_from_2023..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.aer_low_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.aer_high_re_cost_from_2023..co2e_kg:	 nan
# out.emissions.electricity.interior_lighting.aer_95_decarb_by_2050_from_2023..co2e_kg:	 nan
# out.emissions.electricity.enduse_group.hvac.aer_95_decarb_by_2050_from_2023..co2e_kg:	 nan
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 nan
# calc.percent_savings.district_heating.water_systems.energy_consumption_intensity..percent:	 nan
# calc.percent_savings.electricity.interior_lighting.energy_consumption..percent:	 nan
# calc.percent_savings.electricity.pumps.energy_consumption..percent:	 nan
# calc.percent_savings.electricity.pumps.energy_consumption_intensity..percent:	 nan
# out.emissions.electricity.enduse_group.hvac.egrid_2018_subregion..co2e_kg:	 0.9217338219896128
# out.emissions.electricity.enduse_group.hvac.egrid_2019_subregion..co2e_kg:	 0.9217338219896128out.qoi.maximum_daily_use_winter_intensity..w_per_ft2:	 nan
#
# out.qoi.maximum_daily_use_winter..kw:	 nan
# calc.weighted.savings.district_heating.water_systems.energy_consumption..tbtu:	 nan
# calc.weighted.savings.district_heating.cooling.energy_consumption..tbtu:	 nan
# calc.percent_savings.natural_gas.cooling.energy_consumption..percent:	 nan
# calc.percent_savings.natural_gas.cooling.energy_consumption_intensity..percent:	 nan
# out.qoi.maximum_daily_timing_winter_hour..hr:	 nan
# calc.percent_savings.natural_gas.interior_equipment.energy_consumption..percent:	 nan
# calc.percent_savings.natural_gas.interior_equipment.energy_consumption_intensity..percent:	 nanout.emissions.electricity.enduse_group.hvac.egrid_2021_subregion..co2e_kg:	 0.9217338219896126
#
# out.emissions.electricity.enduse_group.hvac.egrid_2020_subregion..co2e_kg:	 0.9217338219896125calc.percent_savings.other_fuel.cooling.energy_consumption..percent:	 nan
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_25_2025_start..co2e_kg:	 0.9210542178834286
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg:	 0.9207846237180874
# out.qoi.median_daily_peak_dec..kw:	 0.9205806759799879
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg:	 0.9199502567343029
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg:	 0.9199487105204027
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg:	 0.9196194151472135
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg:	 0.9195680333025166
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_15_2023_start..co2e_kg:	 0.919559841304171
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg:	 0.9195248766795394
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_15_2025_start..co2e_kg:	 0.9193290337812791
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_15_2023_start..co2e_kg:	 0.9189783754224331
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_25_2025_start..co2e_kg:	 0.9189513804235684
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_30_2023_start..co2e_kg:	 0.9188652958860211
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_30_2023_start..co2e_kg:	 0.9182628977315382
# out.site_energy.total.energy_consumption:	 0.9162960973884505
# out.qoi.minimum_daily_use_winter..kw:	 0.9144717676452179
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_15_2025_start..co2e_kg:	 0.913525295039625
# out.qoi.median_daily_peak_jan..kw:	 0.9120566788379605
# out.qoi.q3_daily_peak_feb..kw:	 0.91006503285692
# out.qoi.q3_daily_peak_dec..kw:	 0.9099932902926968
# calc.emissions.total_with_egrid..co2e_kg:	 0.9050758622438139
#
# calc.percent_savings.other_fuel.cooling.energy_consumption_intensity..percent:	 nan
# out.qoi.q3_daily_peak_jan..kw:	 0.900816221291512
# out.qoi.maximum_daily_peak_feb..kw:	 0.8831977695922547calc.percent_savings.other_fuel.heating.energy_consumption..percent:	 nan
# calc.percent_savings.other_fuel.heating.energy_consumption_intensity..percent:	 nan
# calc.percent_savings.other_fuel.interior_equipment.energy_consumption..percent:	 nan
# calc.percent_savings.other_fuel.interior_equipment.energy_consumption_intensity..percent:	 nan
# calc.percent_savings.electricity.interior_lighting.energy_consumption_intensity..percent:	 nan
# calc.percent_savings.electricity.interior_equipment.energy_consumption_intensity..percent:	 nan
# calc.weighted.savings.electricity.interior_equipment.energy_consumption..tbtu:	 nan
# calc.percent_savings.electricity.interior_equipment.energy_consumption..percent:	 nan
# out.qoi.minimum_daily_use_winter..kw:	 nan
# ...
#     self._target(*self._args, **self._kwargs)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sbose/.conda/envs/DATA_MANAGE/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 6
#       5 with ProcessPoolExecutor(max_workers=cpu_cores) as executor:
# ----> 6     results = list(executor.map(parallel_function, m_states_parallel))
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py:575, in _chain_from_iterable_of_lists(iterable)
#     570 """
#     571 Specialized implementation of itertools.chain.from_iterable.
#     572 Each item in *iterable* should be a list.  This function is
#     573 careful not to keep references to yielded objects.
#     574 """
# --> 575 for element in iterable:
#     576     element.reverse()
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     620 if timeout is None:
# --> 621     yield _result_or_cancel(fs.pop())
#     622 else:
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     318 try:
# --> 319     return fut.result(timeout)
#     320 finally:
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       1 # In this block, we achieve parallelization
#       3 from concurrent.futures import ProcessPoolExecutor
# ----> 5 with ProcessPoolExecutor(max_workers=cpu_cores) as executor:
#       6     results = list(executor.map(parallel_function, m_states_parallel))
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/concurrent/futures/process.py:780, in ProcessPoolExecutor.shutdown(self, wait, cancel_futures)
#     777         self._executor_manager_thread_wakeup.wakeup()
#     779 if self._executor_manager_thread is not None and wait:
# --> 780     self._executor_manager_thread.join()
#     781 # To reduce the risk of opening too many files, remove references to
#     782 # objects that use file descriptors.
#     783 self._executor_manager_thread = None
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/.conda/envs/DATA_MANAGE/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
