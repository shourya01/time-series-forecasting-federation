# %%
# In this script, we set up the basics of downloading the data files for 300,000 buildings from the NREL repository

# The full data lake, which runs on an Amazon S3 server, is hosted at this URL: https://data.openei.org/s3_viewer?bucket=oedi-data-lake&prefix=nrel-pds-building-stock%2F
# Comstock 2024 AMY-1, the release we are looking for, is hosted in this URL: https://data.openei.org/s3_viewer?bucket=oedi-data-lake&prefix=nrel-pds-building-stock%2Fend-use-load-profiles-for-us-building-stock%2F2024%2Fcomstock_amy2018_release_1%2F

# first, we use boto3 to print the directory structure of this release bucket

import boto3 
from botocore import UNSIGNED
from botocore.config import Config

s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))
bucket_name = 'oedi-data-lake'
prefix = 'nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/'

response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter='/')
directories = [content['Prefix'] for content in response.get('CommonPrefixes', [])]

for dir in directories:
    print(dir)
# Out:
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/building_energy_models/
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/comparison_plots/
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/geographic_information/
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata_and_annual_results/
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/timeseries_aggregates/
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/timeseries_individual_buildings/
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/weather/

# %%
# we now explore the files present in metadata folder

prefix = 'nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/'

paginator = s3.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket=bucket_name, Prefix=prefix)

files = []
for page in pages:
    for obj in page.get('Contents', []):
        files.append(obj['Key'])

for file in files:
    print(file)
# Out:
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/baseline.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade01.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade02.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade03.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade05.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade06.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade07.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade08.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade09.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade10.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade11.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade12.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade13.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade14.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade15.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade16.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade17.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade18.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade19.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade20.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade21.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade22.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade23.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade24.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade25.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade26.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade27.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade28.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade29.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade31.parquet
# nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade32.parquet

# %%
# We now explore the metadata of the latest update. While doing the same, we will also store the latest update number which might be useful later.

import pandas as pd
import s3fs
import os

fs = s3fs.S3FileSystem(anon=True)
file_path = 'nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/metadata/upgrade32.parquet'
base_path = '/lcrc/project/NEXTGENOPT/NREL_COMSTOCK_DATA' # base path where the files are downloaded

update_version = ''.join(filter(str.isdigit, os.path.basename(file_path))) # version of the update which we are using

with fs.open(f's3://{bucket_name}/{file_path}') as f:
    df = pd.read_parquet(f)
    
# Also save the metadata file to disk
fs.get(f's3://{bucket_name}/{file_path}', base_path)
# Out:
# [None]

# %%
# We now explore the columns of the parquet file we just downloaded

col_values = df.columns.tolist()

for cval in col_values:
    print(cval)
# Out:
# metadata_index
# upgrade
# weight
# in.sqft
# calc.weighted.sqft
# in.upgrade_name
# applicability
# in.building_america_climate_zone
# in.cambium_grid_region
# in.census_division_name
# in.census_region_name
# in.cluster_id
# in.cluster_name
# in.county_name
# in.iso_rto_region
# in.nhgis_county_gisjoin
# in.nhgis_puma_gisjoin
# in.nhgis_tract_gisjoin
# in.reeds_balancing_area
# in.state
# in.state_name
# in.airtightness..m3_per_m2_s
# in.ashrae_iecc_climate_zone_2006
# in.aspect_ratio
# in.building_subtype
# in.cejst_is_disadvantaged
# in.comstock_building_type
# in.comstock_building_type_group
# in.economizer_changeover_temperature_fault_applicable
# in.economizer_damper_stuck_fault_applicable
# in.economizer_damper_stuck_fault_timing
# in.ejscreen_census_tract_percentile_for_demographic_index
# in.ejscreen_census_tract_percentile_for_less_than_hs_educ
# in.ejscreen_census_tract_percentile_for_low_income
# in.ejscreen_census_tract_percentile_for_people_in_ling_isol
# in.ejscreen_census_tract_percentile_for_people_of_color
# in.ejscreen_census_tract_percentile_for_people_over_64
# in.ejscreen_census_tract_percentile_percent_people_under_5
# in.energy_code_followed_during_last_ext_lighting_replacement
# in.energy_code_followed_during_last_hvac_replacement
# in.energy_code_followed_during_last_int_equipment_replacement
# in.energy_code_followed_during_last_roof_replacement
# in.energy_code_followed_during_last_svc_water_htg_replacement
# in.energy_code_followed_during_last_walls_replacement
# in.energy_code_followed_during_original_building_construction
# in.floor_area_category
# in.heating_fuel
# in.hvac_category
# in.hvac_combined_type
# in.hvac_cool_type
# in.hvac_heat_type
# in.hvac_night_variability
# in.hvac_system_type
# in.hvac_vent_type
# in.interior_lighting_generation
# in.number_of_stories
# in.number_stories
# in.ownership_type
# in.party_responsible_for_operation
# in.purchase_input_responsibility
# in.rotation..degrees
# in.service_water_heating_fuel
# in.tstat_clg_delta_f..delta_f
# in.tstat_clg_sp_f..f
# in.tstat_htg_delta_f..delta_f
# in.tstat_htg_sp_f..f
# in.vintage
# in.wall_construction_type
# in.weather_file_2018
# in.weather_file_tmy3
# in.weekday_opening_time..hr
# in.weekday_operating_hours..hr
# in.weekend_opening_time..hr
# in.weekend_operating_hours..hr
# in.window_to_wall_ratio_category
# in.window_type
# in.year_built
# out.district_cooling.cooling.energy_consumption
# out.district_cooling.cooling.energy_savings
# out.district_cooling.total.energy_consumption
# out.district_cooling.total.energy_savings
# out.district_heating.cooling.energy_consumption
# out.district_heating.cooling.energy_savings
# out.district_heating.heating.energy_consumption
# out.district_heating.heating.energy_savings
# out.district_heating.total.energy_consumption
# out.district_heating.total.energy_savings
# out.district_heating.water_systems.energy_consumption
# out.district_heating.water_systems.energy_savings
# out.electricity.cooling.energy_consumption
# out.electricity.cooling.energy_savings
# out.electricity.exterior_lighting.energy_consumption
# out.electricity.exterior_lighting.energy_savings
# out.electricity.fans.energy_consumption
# out.electricity.fans.energy_savings
# out.electricity.heat_recovery.energy_consumption
# out.electricity.heat_recovery.energy_savings
# out.electricity.heat_rejection.energy_consumption
# out.electricity.heat_rejection.energy_savings
# out.electricity.heating.energy_consumption
# out.electricity.heating.energy_savings
# out.electricity.interior_equipment.energy_consumption
# out.electricity.interior_equipment.energy_savings
# out.electricity.interior_lighting.energy_consumption
# out.electricity.interior_lighting.energy_savings
# out.electricity.pumps.energy_consumption
# out.electricity.pumps.energy_savings
# out.electricity.refrigeration.energy_consumption
# out.electricity.refrigeration.energy_savings
# out.electricity.total.apr.energy_consumption..kwh
# out.electricity.total.aug.energy_consumption..kwh
# out.electricity.total.dec.energy_consumption..kwh
# out.electricity.total.energy_consumption
# out.electricity.total.energy_savings
# out.electricity.total.feb.energy_consumption..kwh
# out.electricity.total.jan.energy_consumption..kwh
# out.electricity.total.jul.energy_consumption..kwh
# out.electricity.total.jun.energy_consumption..kwh
# out.electricity.total.mar.energy_consumption..kwh
# out.electricity.total.may.energy_consumption..kwh
# out.electricity.total.nov.energy_consumption..kwh
# out.electricity.total.oct.energy_consumption..kwh
# out.electricity.total.sep.energy_consumption..kwh
# out.electricity.water_systems.energy_consumption
# out.electricity.water_systems.energy_savings
# out.natural_gas.cooling.energy_savings
# out.natural_gas.heating.energy_consumption
# out.natural_gas.heating.energy_savings
# out.natural_gas.interior_equipment.energy_consumption
# out.natural_gas.interior_equipment.energy_savings
# out.natural_gas.total.energy_consumption
# out.natural_gas.total.energy_savings
# out.natural_gas.water_systems.energy_consumption
# out.natural_gas.water_systems.energy_savings
# out.other_fuel.cooling.energy_consumption
# out.other_fuel.cooling.energy_savings
# out.other_fuel.heating.energy_consumption
# out.other_fuel.heating.energy_savings
# out.other_fuel.interior_equipment.energy_savings
# out.other_fuel.total.energy_consumption
# out.other_fuel.total.energy_savings
# out.other_fuel.water_systems.energy_consumption
# out.other_fuel.water_systems.energy_savings
# out.site_energy.total.energy_consumption
# out.site_energy.total.energy_savings
# out.electricity.total.peak_demand
# out.district_cooling.cooling.energy_consumption_intensity
# out.district_cooling.cooling.energy_savings_intensity
# out.district_cooling.total.energy_consumption_intensity
# out.district_cooling.total.energy_savings_intensity
# out.district_heating.cooling.energy_consumption_intensity
# out.district_heating.cooling.energy_savings_intensity
# out.district_heating.heating.energy_consumption_intensity
# out.district_heating.heating.energy_savings_intensity
# out.district_heating.total.energy_consumption_intensity
# out.district_heating.total.energy_savings_intensity
# out.district_heating.water_systems.energy_consumption_intensity
# out.district_heating.water_systems.energy_savings_intensity
# out.electricity.cooling.energy_consumption_intensity
# out.electricity.cooling.energy_savings_intensity
# out.electricity.exterior_lighting.energy_consumption_intensity
# out.electricity.exterior_lighting.energy_savings_intensity
# out.electricity.fans.energy_consumption_intensity
# out.electricity.fans.energy_savings_intensity
# out.electricity.heat_recovery.energy_consumption_intensity
# out.electricity.heat_recovery.energy_savings_intensity
# out.electricity.heat_rejection.energy_consumption_intensity
# out.electricity.heat_rejection.energy_savings_intensity
# out.electricity.heating.energy_consumption_intensity
# out.electricity.heating.energy_savings_intensity
# out.electricity.interior_equipment.energy_consumption_intensity
# out.electricity.interior_equipment.energy_savings_intensity
# out.electricity.interior_lighting.energy_consumption_intensity
# out.electricity.interior_lighting.energy_savings_intensity
# out.electricity.pumps.energy_consumption_intensity
# out.electricity.pumps.energy_savings_intensity
# out.electricity.refrigeration.energy_consumption_intensity
# out.electricity.refrigeration.energy_savings_intensity
# out.electricity.total.energy_consumption_intensity
# out.electricity.total.energy_savings_intensity
# out.electricity.water_systems.energy_consumption_intensity
# out.electricity.water_systems.energy_savings_intensity
# out.natural_gas.cooling.energy_consumption_intensity
# out.natural_gas.cooling.energy_savings_intensity
# out.natural_gas.heating.energy_consumption_intensity
# out.natural_gas.heating.energy_savings_intensity
# out.natural_gas.interior_equipment.energy_consumption_intensity
# out.natural_gas.interior_equipment.energy_savings_intensity
# out.natural_gas.total.energy_consumption_intensity
# out.natural_gas.total.energy_savings_intensity
# out.natural_gas.water_systems.energy_consumption_intensity
# out.natural_gas.water_systems.energy_savings_intensity
# out.other_fuel.cooling.energy_consumption_intensity
# out.other_fuel.cooling.energy_savings_intensity
# out.other_fuel.heating.energy_consumption_intensity
# out.other_fuel.heating.energy_savings_intensity
# out.other_fuel.interior_equipment.energy_consumption_intensity
# out.other_fuel.interior_equipment.energy_savings_intensity
# out.other_fuel.total.energy_consumption_intensity
# out.other_fuel.total.energy_savings_intensity
# out.other_fuel.water_systems.energy_consumption_intensity
# out.other_fuel.water_systems.energy_savings_intensity
# out.site_energy.total.energy_consumption_intensity
# out.site_energy.total.energy_savings_intensity
# out.qoi.maximum_daily_peak_apr..kw
# out.qoi.maximum_daily_peak_aug..kw
# out.qoi.maximum_daily_peak_dec..kw
# out.qoi.maximum_daily_peak_feb..kw
# out.qoi.maximum_daily_peak_jan..kw
# out.qoi.maximum_daily_peak_jul..kw
# out.qoi.maximum_daily_peak_jun..kw
# out.qoi.maximum_daily_peak_mar..kw
# out.qoi.maximum_daily_peak_may..kw
# out.qoi.maximum_daily_peak_nov..kw
# out.qoi.maximum_daily_peak_oct..kw
# out.qoi.maximum_daily_peak_sep..kw
# out.qoi.maximum_daily_timing_shoulder_hour..hr
# out.qoi.maximum_daily_timing_summer_hour..hr
# out.qoi.maximum_daily_timing_winter_hour..hr
# out.qoi.maximum_daily_use_shoulder..kw
# out.qoi.maximum_daily_use_shoulder_intensity..w_per_ft2
# out.qoi.maximum_daily_use_summer..kw
# out.qoi.maximum_daily_use_summer_intensity..w_per_ft2
# out.qoi.maximum_daily_use_winter..kw
# out.qoi.maximum_daily_use_winter_intensity..w_per_ft2
# out.qoi.median_daily_peak_apr..kw
# out.qoi.median_daily_peak_aug..kw
# out.qoi.median_daily_peak_dec..kw
# out.qoi.median_daily_peak_feb..kw
# out.qoi.median_daily_peak_jan..kw
# out.qoi.median_daily_peak_jul..kw
# out.qoi.median_daily_peak_jun..kw
# out.qoi.median_daily_peak_mar..kw
# out.qoi.median_daily_peak_may..kw
# out.qoi.median_daily_peak_nov..kw
# out.qoi.median_daily_peak_oct..kw
# out.qoi.median_daily_peak_sep..kw
# out.qoi.median_daily_peak_timing_apr..hr
# out.qoi.median_daily_peak_timing_aug..hr
# out.qoi.median_daily_peak_timing_dec..hr
# out.qoi.median_daily_peak_timing_feb..hr
# out.qoi.median_daily_peak_timing_jan..hr
# out.qoi.median_daily_peak_timing_jul..hr
# out.qoi.median_daily_peak_timing_jun..hr
# out.qoi.median_daily_peak_timing_mar..hr
# out.qoi.median_daily_peak_timing_may..hr
# out.qoi.median_daily_peak_timing_nov..hr
# out.qoi.median_daily_peak_timing_oct..hr
# out.qoi.median_daily_peak_timing_sep..hr
# out.qoi.minimum_daily_peak_apr..kw
# out.qoi.minimum_daily_peak_aug..kw
# out.qoi.minimum_daily_peak_dec..kw
# out.qoi.minimum_daily_peak_feb..kw
# out.qoi.minimum_daily_peak_jan..kw
# out.qoi.minimum_daily_peak_jul..kw
# out.qoi.minimum_daily_peak_jun..kw
# out.qoi.minimum_daily_peak_mar..kw
# out.qoi.minimum_daily_peak_may..kw
# out.qoi.minimum_daily_peak_nov..kw
# out.qoi.minimum_daily_peak_oct..kw
# out.qoi.minimum_daily_peak_sep..kw
# out.qoi.minimum_daily_use_shoulder..kw
# out.qoi.minimum_daily_use_shoulder_intensity..w_per_ft2
# out.qoi.minimum_daily_use_summer..kw
# out.qoi.minimum_daily_use_summer_intensity..w_per_ft2
# out.qoi.minimum_daily_use_winter..kw
# out.qoi.minimum_daily_use_winter_intensity..w_per_ft2
# out.qoi.q1_daily_peak_apr..kw
# out.qoi.q1_daily_peak_aug..kw
# out.qoi.q1_daily_peak_dec..kw
# out.qoi.q1_daily_peak_feb..kw
# out.qoi.q1_daily_peak_jan..kw
# out.qoi.q1_daily_peak_jul..kw
# out.qoi.q1_daily_peak_jun..kw
# out.qoi.q1_daily_peak_mar..kw
# out.qoi.q1_daily_peak_may..kw
# out.qoi.q1_daily_peak_nov..kw
# out.qoi.q1_daily_peak_oct..kw
# out.qoi.q1_daily_peak_sep..kw
# out.qoi.q3_daily_peak_apr..kw
# out.qoi.q3_daily_peak_aug..kw
# out.qoi.q3_daily_peak_dec..kw
# out.qoi.q3_daily_peak_feb..kw
# out.qoi.q3_daily_peak_jan..kw
# out.qoi.q3_daily_peak_jul..kw
# out.qoi.q3_daily_peak_jun..kw
# out.qoi.q3_daily_peak_mar..kw
# out.qoi.q3_daily_peak_may..kw
# out.qoi.q3_daily_peak_nov..kw
# out.qoi.q3_daily_peak_oct..kw
# out.qoi.q3_daily_peak_sep..kw
# out.emissions.electricity.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.cooling.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.cooling.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.cooling.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.cooling.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.cooling.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.cooling.egrid_2018_state..co2e_kg
# out.emissions.electricity.cooling.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.cooling.egrid_2019_state..co2e_kg
# out.emissions.electricity.cooling.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.cooling.egrid_2020_state..co2e_kg
# out.emissions.electricity.cooling.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.cooling.egrid_2021_state..co2e_kg
# out.emissions.electricity.cooling.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.cooling.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.cooling.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.egrid_2018_state..co2e_kg
# out.emissions.electricity.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.egrid_2019_state..co2e_kg
# out.emissions.electricity.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.egrid_2020_state..co2e_kg
# out.emissions.electricity.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.egrid_2021_state..co2e_kg
# out.emissions.electricity.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.enduse_group.hvac.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.enduse_group.hvac.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.enduse_group.hvac.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.enduse_group.hvac.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.enduse_group.hvac.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2018_state..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2019_state..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2020_state..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2021_state..co2e_kg
# out.emissions.electricity.enduse_group.hvac.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.enduse_group.hvac.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.exterior_lighting.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.exterior_lighting.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.exterior_lighting.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.exterior_lighting.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2018_state..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2019_state..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2020_state..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2021_state..co2e_kg
# out.emissions.electricity.exterior_lighting.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.exterior_lighting.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.heating.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.heating.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.heating.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.heating.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.heating.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.heating.egrid_2018_state..co2e_kg
# out.emissions.electricity.heating.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.heating.egrid_2019_state..co2e_kg
# out.emissions.electricity.heating.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.heating.egrid_2020_state..co2e_kg
# out.emissions.electricity.heating.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.heating.egrid_2021_state..co2e_kg
# out.emissions.electricity.heating.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.heating.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.heating.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.heating.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.heating.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.heating.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.heating.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.interior_equipment.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.interior_equipment.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.interior_equipment.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.interior_equipment.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2018_state..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2019_state..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2020_state..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2021_state..co2e_kg
# out.emissions.electricity.interior_equipment.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.interior_equipment.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.interior_equipment_fuel_oil_ghg_emissions..co2e_kg
# out.emissions.electricity.interior_equipment_natural_gas_ghg_emissions..co2e_kg
# out.emissions.electricity.interior_equipment_propane_ghg_emissions..co2e_kg
# out.emissions.electricity.interior_lighting.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.interior_lighting.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.interior_lighting.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.interior_lighting.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.interior_lighting.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2018_state..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2019_state..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2020_state..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2021_state..co2e_kg
# out.emissions.electricity.interior_lighting.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.interior_lighting.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.refrigeration.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.refrigeration.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.refrigeration.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.refrigeration.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2018_state..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2019_state..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2020_state..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2021_state..co2e_kg
# out.emissions.electricity.refrigeration.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.refrigeration.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.electricity.water_systems.aer_95_decarb_by_2035_from_2023..co2e_kg
# out.emissions.electricity.water_systems.aer_95_decarb_by_2050_from_2023..co2e_kg
# out.emissions.electricity.water_systems.aer_high_re_cost_from_2023..co2e_kg
# out.emissions.electricity.water_systems.aer_low_re_cost_from_2023..co2e_kg
# out.emissions.electricity.water_systems.aer_mid_case_from_2023..co2e_kg
# out.emissions.electricity.water_systems.egrid_2018_state..co2e_kg
# out.emissions.electricity.water_systems.egrid_2018_subregion..co2e_kg
# out.emissions.electricity.water_systems.egrid_2019_state..co2e_kg
# out.emissions.electricity.water_systems.egrid_2019_subregion..co2e_kg
# out.emissions.electricity.water_systems.egrid_2020_state..co2e_kg
# out.emissions.electricity.water_systems.egrid_2020_subregion..co2e_kg
# out.emissions.electricity.water_systems.egrid_2021_state..co2e_kg
# out.emissions.electricity.water_systems.egrid_2021_subregion..co2e_kg
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_15_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_15_2025_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_25_2025_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2035_30_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2050_15_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_95_decarb_by_2050_30_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_high_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_high_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_low_re_cost_15_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_low_re_cost_15_2025_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_low_re_cost_25_2025_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_low_re_cost_30_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_mid_case_15_2023_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_mid_case_15_2025_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_mid_case_25_2025_start..co2e_kg
# out.emissions.electricity.water_systems.lrmer_mid_case_30_2023_start..co2e_kg
# out.emissions.fuel_oil..co2e_kg
# out.emissions.fuel_oil.enduse_group.hvac..co2e_kg
# out.emissions.fuel_oil.heating..co2e_kg
# out.emissions.fuel_oil.water_systems..co2e_kg
# out.emissions.natural_gas..co2e_kg
# out.emissions.natural_gas.enduse_group.hvac..co2e_kg
# out.emissions.natural_gas.heating..co2e_kg
# out.emissions.natural_gas.water_systems..co2e_kg
# out.emissions.propane..co2e_kg
# out.emissions.propane.enduse_group.hvac..co2e_kg
# out.emissions.propane.heating..co2e_kg
# out.emissions.propane.water_systems..co2e_kg
# out.utility_bills.electricity_bill_intensity..usd_per_ft2
# out.utility_bills.electricity_bill_max..usd
# out.utility_bills.electricity_bill_mean..usd
# out.utility_bills.electricity_bill_median..usd
# out.utility_bills.electricity_bill_min..usd
# out.utility_bills.electricity_bill_number_of_rates..usd
# out.utility_bills.electricity_energy_rate..usd_per_kwh
# out.utility_bills.electricity_utility_eia_id
# out.utility_bills.fuel_oil_bill..usd
# out.utility_bills.fuel_oil_bill_intensity..usd_per_ft2
# out.utility_bills.fuel_oil_rate_name
# out.utility_bills.natural_gas_bill..usd
# out.utility_bills.natural_gas_bill_intensity..usd_per_ft2
# out.utility_bills.natural_gas_energy_rate..usd_per_kwh
# out.utility_bills.natural_gas_rate_name
# out.utility_bills.propane_bill..usd
# out.utility_bills.propane_bill_intensity..usd_per_ft2
# out.utility_bills.propane_rate_name
# out.params.air_system_fan_power_minimum_flow_fraction
# out.params.air_system_fan_static_pressure..inwc
# out.params.air_system_fan_total_efficiency
# out.params.area_fraction_with_dcv
# out.params.area_fraction_with_economizer
# out.params.area_fraction_with_heat_recovery
# out.params.area_fraction_with_motorized_oa_damper
# out.params.area_fraction_with_mz_vav_optimization
# out.params.area_fraction_with_supply_air_temperature_reset
# out.params.area_fraction_with_unoccupied_shutdown
# out.params.average_cooling_setpoint_max..c
# out.params.average_cooling_setpoint_min..c
# out.params.average_heating_setpoint_max..c
# out.params.average_heating_setpoint_min..c
# out.params.average_outdoor_air_fraction
# out.params.average_roof_absorptance
# out.params.average_roof_u_value..btu_per_ft2_f_hr
# out.params.average_wall_u_value..btu_per_ft2_f_hr
# out.params.average_window_shgc
# out.params.average_window_u_value..btu_per_ft2_f_hr
# out.params.average_window_vlt
# out.params.boiler_average_efficiency
# out.params.boiler_cap_weight_efficiency
# out.params.boiler_capacity..kbtu_per_hr
# out.params.boiler_electric..j
# out.params.boiler_gas..j
# out.params.boiler_load..j
# out.params.boiler_load_weight_efficiency
# out.params.boiler_other_fuel..j
# out.params.booster_water_heater_electric..j
# out.params.booster_water_heater_gas..j
# out.params.broiler_fuel_type
# out.params.building_fraction_cooled
# out.params.building_fraction_heated
# out.params.cdd50f
# out.params.cdd65f
# out.params.chiller_average_cop..cop
# out.params.chiller_capacity..tons
# out.params.cooling_equipment_capacity..tons
# out.params.daylight_control_fraction
# out.params.design_chiller_cop..cop
# out.params.design_outdoor_air_flow_rate..m3_per_m2_s
# out.params.dining_type
# out.params.dx_cooling_average_cop..cop
# out.params.dx_cooling_capacity_tons..tons
# out.params.dx_cooling_design_cop..cop
# out.params.dx_cooling_design_eer_135_to_240_kbtuh..eer
# out.params.dx_cooling_design_eer_240_to_760_kbtuh..eer
# out.params.dx_cooling_design_eer_65_to_135_kbtuh..eer
# out.params.dx_cooling_design_eer_760_plus_kbtuh..eer
# out.params.dx_cooling_design_ieer_135_to_240_kbtuh..ieer
# out.params.dx_cooling_design_ieer_240_to_760_kbtuh..ieer
# out.params.dx_cooling_design_ieer_65_to_135_kbtuh..ieer
# out.params.dx_cooling_design_ieer_760_plus_kbtuh..ieer
# out.params.dx_cooling_design_seer_0_to_30_kbtuh..seer
# out.params.dx_cooling_design_seer_30_to_65_kbtuh..seer
# out.params.dx_cooling_electric..j
# out.params.dx_cooling_load..j
# out.params.dx_heating_average_cop..cop
# out.params.dx_heating_average_minimum_operating_temperature..c
# out.params.dx_heating_average_total_cop..cop
# out.params.dx_heating_capacity_at_0f..kbtu_per_hr
# out.params.dx_heating_capacity_at_17f..kbtu_per_hr
# out.params.dx_heating_capacity_at_5f..kbtu_per_hr
# out.params.dx_heating_capacity_at_rated..kbtu_per_hr
# out.params.dx_heating_defrost_energy..kbtu
# out.params.dx_heating_design_cop..cop
# out.params.dx_heating_design_cop_0f..cop
# out.params.dx_heating_design_cop_135_to_240_kbtuh..cop
# out.params.dx_heating_design_cop_17f..cop
# out.params.dx_heating_design_cop_240_plus_kbtuh..cop
# out.params.dx_heating_design_cop_5f..cop
# out.params.dx_heating_design_cop_65_to_135_kbtuh..cop
# out.params.dx_heating_design_hspf_0_to_30_kbtuh..hspf
# out.params.dx_heating_design_hspf_30_to_65_kbtuh..hspf
# out.params.dx_heating_fraction_electric_defrost
# out.params.dx_heating_fraction_electric_supplemental
# out.params.dx_heating_fraction_supplemental
# out.params.dx_heating_hours_below_minus_20f..hr
# out.params.dx_heating_ratio_defrost
# out.params.dx_heating_supplemental_capacity..kbtu_per_hr
# out.params.dx_heating_supplemental_capacity_electric..kbtu_per_hr
# out.params.dx_heating_supplemental_capacity_gas..kbtu_per_hr
# out.params.dx_heating_total_dx_electric..j
# out.params.dx_heating_total_dx_load..j
# out.params.dx_heating_total_load..j
# out.params.dx_heating_total_supplemental_electric..j
# out.params.dx_heating_total_supplemental_gas..j
# out.params.dx_heating_total_supplemental_load..j
# out.params.dx_heating_total_supplemental_load_electric..j
# out.params.dx_heating_total_supplemental_load_gas..j
# out.params.economizer_control_type
# out.params.economizer_high_limit_enthalpy..j_per_kg
# out.params.economizer_high_limit_temperature..c
# out.params.elevator_energy_consumption..kwh
# out.params.ext_roof_area..m2
# out.params.ext_wall_area..m2
# out.params.ext_window_area..m2
# out.params.exterior_lighting_power..w
# out.params.fluid_hx_demand_inlet_temp..c
# out.params.fluid_hx_demand_outlet_temp..c
# out.params.fluid_hx_supply_inlet_temp..c
# out.params.fluid_hx_supply_outlet_temp..c
# out.params.fluid_hx_transfer_energy..j
# out.params.fryer_fuel_type
# out.params.furnace_capacity..kbtu_per_hr
# out.params.gas_coil_average_efficiency
# out.params.ghx_borehole_depth..ft
# out.params.ghx_flow_rate..ft3_per_min
# out.params.ghx_num_boreholes
# out.params.griddle_fuel_type
# out.params.hdd50f
# out.params.hdd65f
# out.params.heat_pump_cooling_average_cop..cop
# out.params.heat_pump_cooling_cap_weight_cop..cop
# out.params.heat_pump_cooling_capacity..kbtu_per_hr
# out.params.heat_pump_cooling_load_weight_cop..cop
# out.params.heat_pump_cooling_source_inlet_temp..c
# out.params.heat_pump_cooling_total_electric..j
# out.params.heat_pump_cooling_total_load..j
# out.params.heat_pump_heating_average_cop..cop
# out.params.heat_pump_heating_cap_weight_cop..cop
# out.params.heat_pump_heating_capacity..kbtu_per_hr
# out.params.heat_pump_heating_load_weight_cop..cop
# out.params.heat_pump_heating_source_inlet_temp..c
# out.params.heat_pump_heating_total_electric..j
# out.params.heat_pump_heating_total_load..j
# out.params.heating_equipment..kbtu_per_hr
# out.params.hot_water_loop_boiler_fraction
# out.params.hot_water_loop_heat_pump_fraction
# out.params.hot_water_loop_load..j
# out.params.hot_water_volume..m3
# out.params.hours_above_65f..hr
# out.params.hours_below_0f..hr
# out.params.hours_below_17f..hr
# out.params.hours_below_50f..hr
# out.params.hours_below_5f..hr
# out.params.hours_cooling_setpoint_not_met..hr
# out.params.hours_heating_setpoint_not_met..hr
# out.params.hp_water_heater_0_to_40_gal_capacity..w
# out.params.hp_water_heater_0_to_40_gal_cop..cop
# out.params.hp_water_heater_0_to_40_gal_count
# out.params.hp_water_heater_0_to_40_gal_total_volume..gal
# out.params.hp_water_heater_40_to_65_gal_capacity..w
# out.params.hp_water_heater_40_to_65_gal_cop..cop
# out.params.hp_water_heater_40_to_65_gal_count
# out.params.hp_water_heater_40_to_65_gal_total_volume..gal
# out.params.hp_water_heater_65_to_90_gal_capacity..w
# out.params.hp_water_heater_65_to_90_gal_cop..cop
# out.params.hp_water_heater_65_to_90_gal_count
# out.params.hp_water_heater_65_to_90_gal_total_volume..gal
# out.params.hp_water_heater_90_plus_capacity..w
# out.params.hp_water_heater_90_plus_gal_cop..cop
# out.params.hp_water_heater_90_plus_gal_count
# out.params.hp_water_heater_90_plus_gal_total_volume..gal
# out.params.hp_water_heater_backup_electric..j
# out.params.hp_water_heater_capacity..w
# out.params.hp_water_heater_cop..cop
# out.params.hp_water_heater_count
# out.params.hp_water_heater_heat_pump_electric..j
# out.params.hp_water_heater_heat_pump_output..j
# out.params.hp_water_heater_tank_output..j
# out.params.hp_water_heater_total_electric..j
# out.params.hp_water_heater_total_output..j
# out.params.hp_water_heater_total_volume..gal
# out.params.hp_water_heater_unmet_heat_transfer_demand..j
# out.params.hvac_count_boilers
# out.params.hvac_count_boilers_0_to_300_kbtuh
# out.params.hvac_count_boilers_2500_plus_kbtuh
# out.params.hvac_count_boilers_300_to_2500_kbtuh
# out.params.hvac_count_chillers_0_to_75_tons
# out.params.hvac_count_chillers_150_to_300_tons
# out.params.hvac_count_chillers_300_to_600_tons
# out.params.hvac_count_chillers_600_plus_tons
# out.params.hvac_count_chillers_75_to_150_tons
# out.params.hvac_count_dx_cooling_0_to_30_kbtuh
# out.params.hvac_count_dx_cooling_135_to_240_kbtuh
# out.params.hvac_count_dx_cooling_240_to_760_kbtuh
# out.params.hvac_count_dx_cooling_30_to_65_kbtuh
# out.params.hvac_count_dx_cooling_65_to_135_kbtuh
# out.params.hvac_count_dx_cooling_760_plus_kbtuh
# out.params.hvac_count_dx_heating_0_to_30_kbtuh
# out.params.hvac_count_dx_heating_135_to_240_kbtuh
# out.params.hvac_count_dx_heating_240_plus_kbtuh
# out.params.hvac_count_dx_heating_30_to_65_kbtuh
# out.params.hvac_count_dx_heating_65_to_135_kbtuh
# out.params.hvac_count_furnace_0_to_30_kbtuh
# out.params.hvac_count_furnace_135_to_240_kbtuh
# out.params.hvac_count_furnace_240_plus_kbtuh
# out.params.hvac_count_furnace_30_to_65_kbtuh
# out.params.hvac_count_furnace_65_to_135_kbtuh
# out.params.hvac_count_heat_pumps_cooling
# out.params.hvac_count_heat_pumps_heating
# out.params.hvac_count_heat_pumps_heating_0_to_300_kbtuh
# out.params.hvac_count_heat_pumps_heating_2500_plus_kbtuh
# out.params.hvac_count_heat_pumps_heating_300_to_2500_kbtuh
# out.params.interior_electric_equipment_eflh..hr
# out.params.interior_electric_equipment_power_density..w_per_ft2
# out.params.interior_lighting_eflh..hr
# out.params.interior_lighting_power_density..w_per_ft2
# out.params.internal_mass_area_ratio
# out.params.non_hp_water_heater_0_to_40_gal_count
# out.params.non_hp_water_heater_0_to_40_gal_total_volume..gal
# out.params.non_hp_water_heater_40_to_65_gal_count
# out.params.non_hp_water_heater_40_to_65_gal_total_volume..gal
# out.params.non_hp_water_heater_65_to_90_gal_count
# out.params.non_hp_water_heater_65_to_90_gal_total_volume..gal
# out.params.non_hp_water_heater_90_plus_gal_count
# out.params.non_hp_water_heater_90_plus_gal_total_volume..gal
# out.params.non_hp_water_heater_count
# out.params.non_hp_water_heater_electric..j
# out.params.non_hp_water_heater_gas..j
# out.params.non_hp_water_heater_other_fuel..j
# out.params.non_hp_water_heater_total_volume_gal..gal
# out.params.non_hp_water_heater_unmet_heat_transfer_demand..j
# out.params.num_air_loops
# out.params.num_air_loops_dcv
# out.params.num_air_loops_economizer
# out.params.num_air_loops_heat_recovery
# out.params.num_broilers
# out.params.num_errors
# out.params.num_fryers
# out.params.num_griddles
# out.params.num_ovens
# out.params.num_ranges
# out.params.num_steamers
# out.params.num_warnings
# out.params.number_of_spaces
# out.params.number_of_surfaces
# out.params.number_of_zones
# out.params.occupant_density_ppl_per_m_2..people_per_m2
# out.params.occupant_eflh..hr
# out.params.oven_fuel_type
# out.params.range_fuel_type
# out.params.smallest_space_floor_area..m2
# out.params.steamer_fuel_type
# out.params.vrf_area_average_indoor_unit_cooling_capacity..w
# out.params.vrf_area_average_indoor_unit_heating_capacity..w
# out.params.vrf_average_line_height..m
# out.params.vrf_average_line_length..m
# out.params.vrf_average_num_compressors
# out.params.vrf_average_outdoor_unit_cooling_capacity..w
# out.params.vrf_average_outdoor_unit_heating_capacity..w
# out.params.vrf_cooling_average_cop
# out.params.vrf_cooling_design_cop
# out.params.vrf_cooling_design_cop_110f
# out.params.vrf_cooling_design_cop_35f
# out.params.vrf_cooling_design_cop_60f
# out.params.vrf_cooling_design_cop_85f
# out.params.vrf_heating_average_cop
# out.params.vrf_heating_average_total_cop
# out.params.vrf_heating_design_cop
# out.params.vrf_heating_design_cop_0f
# out.params.vrf_heating_design_cop_20f
# out.params.vrf_heating_design_cop_40f
# out.params.vrf_heating_design_cop_minus22f
# out.params.vrf_heating_fraction_supplemental
# out.params.vrf_heating_total_supplemental_electric..j
# out.params.vrf_heating_total_supplemental_gas..j
# out.params.vrf_heating_total_supplemental_load..j
# out.params.vrf_heating_total_supplemental_load_electric..j
# out.params.vrf_heating_total_supplemental_load_gas..j
# out.params.vrf_indoor_unit_count
# out.params.vrf_outdoor_unit_count
# out.params.vrf_temperature_type
# out.params.vrf_total_cooling_load..j
# out.params.vrf_total_heat_recovery..j
# out.params.vrf_total_heating_load..j
# out.params.vrf_total_indoor_unit_cooling_capacity..w
# out.params.vrf_total_indoor_unit_heating_capacity..w
# out.params.vrf_total_outdoor_unit_cooling_capacity..w
# out.params.vrf_total_outdoor_unit_heating_capacity..w
# out.params.wa_hp_cooling_average_cop..cop
# out.params.wa_hp_cooling_capacity..w
# out.params.wa_hp_cooling_design_cop..cop
# out.params.wa_hp_cooling_electric..j
# out.params.wa_hp_cooling_load..j
# out.params.wa_hp_heating_average_cop..cop
# out.params.wa_hp_heating_capacity..w
# out.params.wa_hp_heating_design_cop..cop
# out.params.wa_hp_heating_electric..j
# out.params.wa_hp_heating_load..j
# out.params.window_to_wall_ratio
# out.params.zone_hvac_fan_power_minimum_flow_fraction
# out.params.zone_hvac_fan_static_pressure..inwc
# out.params.zone_hvac_fan_total_efficiency
# calc.emissions.total_with_cambium_mid_case_15y..co2e_kg
# calc.emissions.total_with_egrid..co2e_kg
# calc.enduse_group.district_cooling.hvac.energy_consumption..kwh
# calc.enduse_group.district_heating.hvac.energy_consumption..kwh
# calc.enduse_group.district_heating.water_systems.energy_consumption..kwh
# calc.enduse_group.electricity.hvac.energy_consumption..kwh
# calc.enduse_group.electricity.interior_equipment.energy_consumption..kwh
# calc.enduse_group.electricity.lighting.energy_consumption..kwh
# calc.enduse_group.electricity.refrigeration.energy_consumption..kwh
# calc.enduse_group.electricity.water_systems.energy_consumption..kwh
# calc.enduse_group.natural_gas.hvac.energy_consumption..kwh
# calc.enduse_group.natural_gas.interior_equipment.energy_consumption..kwh
# calc.enduse_group.natural_gas.water_systems.energy_consumption..kwh
# calc.enduse_group.other_fuel.hvac.energy_consumption..kwh
# calc.enduse_group.other_fuel.interior_equipment.energy_consumption..kwh
# calc.enduse_group.other_fuel.water_systems.energy_consumption..kwh
# calc.enduse_group.site_energy.cooling.energy_consumption..kwh
# calc.enduse_group.site_energy.heating.energy_consumption..kwh
# calc.enduse_group.site_energy.hvac.energy_consumption..kwh
# calc.enduse_group.site_energy.interior_equipment.energy_consumption..kwh
# calc.enduse_group.site_energy.lighting.energy_consumption..kwh
# calc.enduse_group.site_energy.refrigeration.energy_consumption..kwh
# calc.enduse_group.site_energy.water_systems.energy_consumption..kwh
# calc.percent_savings.district_cooling.cooling.energy_consumption..percent
# calc.percent_savings.district_cooling.cooling.energy_consumption_intensity..percent
# calc.percent_savings.district_cooling.total.energy_consumption..percent
# calc.percent_savings.district_cooling.total.energy_consumption_intensity..percent
# calc.percent_savings.district_heating.cooling.energy_consumption..percent
# calc.percent_savings.district_heating.cooling.energy_consumption_intensity..percent
# calc.percent_savings.district_heating.heating.energy_consumption..percent
# calc.percent_savings.district_heating.heating.energy_consumption_intensity..percent
# calc.percent_savings.district_heating.total.energy_consumption..percent
# calc.percent_savings.district_heating.total.energy_consumption_intensity..percent
# calc.percent_savings.district_heating.water_systems.energy_consumption..percent
# calc.percent_savings.district_heating.water_systems.energy_consumption_intensity..percent
# calc.percent_savings.electricity.cooling.energy_consumption..percent
# calc.percent_savings.electricity.cooling.energy_consumption_intensity..percent
# calc.percent_savings.electricity.exterior_lighting.energy_consumption..percent
# calc.percent_savings.electricity.exterior_lighting.energy_consumption_intensity..percent
# calc.percent_savings.electricity.fans.energy_consumption..percent
# calc.percent_savings.electricity.fans.energy_consumption_intensity..percent
# calc.percent_savings.electricity.heat_recovery.energy_consumption..percent
# calc.percent_savings.electricity.heat_recovery.energy_consumption_intensity..percent
# calc.percent_savings.electricity.heat_rejection.energy_consumption..percent
# calc.percent_savings.electricity.heat_rejection.energy_consumption_intensity..percent
# calc.percent_savings.electricity.heating.energy_consumption..percent
# calc.percent_savings.electricity.heating.energy_consumption_intensity..percent
# calc.percent_savings.electricity.interior_equipment.energy_consumption..percent
# calc.percent_savings.electricity.interior_equipment.energy_consumption_intensity..percent
# calc.percent_savings.electricity.interior_lighting.energy_consumption..percent
# calc.percent_savings.electricity.interior_lighting.energy_consumption_intensity..percent
# calc.percent_savings.electricity.pumps.energy_consumption..percent
# calc.percent_savings.electricity.pumps.energy_consumption_intensity..percent
# calc.percent_savings.electricity.refrigeration.energy_consumption..percent
# calc.percent_savings.electricity.refrigeration.energy_consumption_intensity..percent
# calc.percent_savings.electricity.total.energy_consumption..percent
# calc.percent_savings.electricity.total.energy_consumption_intensity..percent
# calc.percent_savings.electricity.water_systems.energy_consumption..percent
# calc.percent_savings.electricity.water_systems.energy_consumption_intensity..percent
# calc.percent_savings.natural_gas.cooling.energy_consumption..percent
# calc.percent_savings.natural_gas.cooling.energy_consumption_intensity..percent
# calc.percent_savings.natural_gas.heating.energy_consumption..percent
# calc.percent_savings.natural_gas.heating.energy_consumption_intensity..percent
# calc.percent_savings.natural_gas.interior_equipment.energy_consumption..percent
# calc.percent_savings.natural_gas.interior_equipment.energy_consumption_intensity..percent
# calc.percent_savings.natural_gas.total.energy_consumption..percent
# calc.percent_savings.natural_gas.total.energy_consumption_intensity..percent
# calc.percent_savings.natural_gas.water_systems.energy_consumption..percent
# calc.percent_savings.natural_gas.water_systems.energy_consumption_intensity..percent
# calc.percent_savings.other_fuel.cooling.energy_consumption..percent
# calc.percent_savings.other_fuel.cooling.energy_consumption_intensity..percent
# calc.percent_savings.other_fuel.heating.energy_consumption..percent
# calc.percent_savings.other_fuel.heating.energy_consumption_intensity..percent
# calc.percent_savings.other_fuel.interior_equipment.energy_consumption..percent
# calc.percent_savings.other_fuel.interior_equipment.energy_consumption_intensity..percent
# calc.percent_savings.other_fuel.total.energy_consumption..percent
# calc.percent_savings.other_fuel.total.energy_consumption_intensity..percent
# calc.percent_savings.other_fuel.water_systems.energy_consumption..percent
# calc.percent_savings.other_fuel.water_systems.energy_consumption_intensity..percent
# calc.percent_savings.site_energy.total.energy_consumption..percent
# calc.percent_savings.site_energy.total.energy_consumption_intensity..percent
# calc.segment
# calc.weighted.district_cooling.cooling.energy_consumption..tbtu
# calc.weighted.district_cooling.total.energy_consumption..tbtu
# calc.weighted.district_heating.cooling.energy_consumption..tbtu
# calc.weighted.district_heating.heating.energy_consumption..tbtu
# calc.weighted.district_heating.total.energy_consumption..tbtu
# calc.weighted.district_heating.water_systems.energy_consumption..tbtu
# calc.weighted.electricity.cooling.energy_consumption..tbtu
# calc.weighted.electricity.exterior_lighting.energy_consumption..tbtu
# calc.weighted.electricity.fans.energy_consumption..tbtu
# calc.weighted.electricity.heat_recovery.energy_consumption..tbtu
# calc.weighted.electricity.heat_rejection.energy_consumption..tbtu
# calc.weighted.electricity.heating.energy_consumption..tbtu
# calc.weighted.electricity.interior_equipment.energy_consumption..tbtu
# calc.weighted.electricity.interior_lighting.energy_consumption..tbtu
# calc.weighted.electricity.pumps.energy_consumption..tbtu
# calc.weighted.electricity.refrigeration.energy_consumption..tbtu
# calc.weighted.electricity.total.energy_consumption..tbtu
# calc.weighted.electricity.water_systems.energy_consumption..tbtu
# calc.weighted.emissions.electricity.egrid_2021_subregion..co2e_mmt
# calc.weighted.emissions.electricity.lrmer_high_re_cost_15_2023_start..co2e_mmt
# calc.weighted.emissions.electricity.lrmer_low_re_cost_15_2023_start..co2e_mmt
# calc.weighted.emissions.fuel_oil..co2e_mmt
# calc.weighted.emissions.natural_gas..co2e_mmt
# calc.weighted.emissions.propane..co2e_mmt
# calc.weighted.emissions.total_with_cambium_mid_case_15y..co2e_mmt
# calc.weighted.emissions.total_with_egrid..co2e_mmt
# calc.weighted.enduse_group.district_cooling.hvac.energy_consumption..tbtu
# calc.weighted.enduse_group.district_heating.hvac.energy_consumption..tbtu
# calc.weighted.enduse_group.district_heating.interior_equipment.energy_consumption..tbtu
# calc.weighted.enduse_group.district_heating.water_systems.energy_consumption..tbtu
# calc.weighted.enduse_group.electricity.hvac.emissions.egrid_2021_subregion..co2e_mmt
# calc.weighted.enduse_group.electricity.hvac.energy_consumption..tbtu
# calc.weighted.enduse_group.electricity.interior_equipment.emissions.egrid_2021_subregion..co2e_mmt
# calc.weighted.enduse_group.electricity.interior_equipment.energy_consumption..tbtu
# calc.weighted.enduse_group.electricity.lighting.emissions.egrid_2021_subregion..co2e_mmt
# calc.weighted.enduse_group.electricity.lighting.energy_consumption..tbtu
# calc.weighted.enduse_group.electricity.refrigeration.emissions.egrid_2021_subregion..co2e_mmt
# calc.weighted.enduse_group.electricity.refrigeration.energy_consumption..tbtu
# calc.weighted.enduse_group.electricity.water_systems.emissions.egrid_2021_subregion..co2e_mmt
# calc.weighted.enduse_group.electricity.water_systems.energy_consumption..tbtu
# calc.weighted.enduse_group.natural_gas.hvac.emissions..co2e_mmt
# calc.weighted.enduse_group.natural_gas.hvac.energy_consumption..tbtu
# calc.weighted.enduse_group.natural_gas.interior_equipment.emissions..co2e_mmt
# calc.weighted.enduse_group.natural_gas.interior_equipment.energy_consumption..tbtu
# calc.weighted.enduse_group.natural_gas.water_systems.emissions..co2e_mmt
# calc.weighted.enduse_group.natural_gas.water_systems.energy_consumption..tbtu
# calc.weighted.enduse_group.other_fuel.hvac.emissions..co2e_mmt
# calc.weighted.enduse_group.other_fuel.hvac.energy_consumption..tbtu
# calc.weighted.enduse_group.other_fuel.interior_equipment.emissions..co2e_mmt
# calc.weighted.enduse_group.other_fuel.interior_equipment.energy_consumption..tbtu
# calc.weighted.enduse_group.other_fuel.water_systems.emissions..co2e_mmt
# calc.weighted.enduse_group.other_fuel.water_systems.energy_consumption..tbtu
# calc.weighted.enduse_group.site_energy.hvac.emissions..co2e_mmt
# calc.weighted.enduse_group.site_energy.hvac.energy_consumption..tbtu
# calc.weighted.enduse_group.site_energy.interior_equipment.emissions..co2e_mmt
# calc.weighted.enduse_group.site_energy.interior_equipment.energy_consumption..tbtu
# calc.weighted.enduse_group.site_energy.lighting.emissions..co2e_mmt
# calc.weighted.enduse_group.site_energy.lighting.energy_consumption..tbtu
# calc.weighted.enduse_group.site_energy.refrigeration.emissions..co2e_mmt
# calc.weighted.enduse_group.site_energy.refrigeration.energy_consumption..tbtu
# calc.weighted.enduse_group.site_energy.water_systems.emissions..co2e_mmt
# calc.weighted.enduse_group.site_energy.water_systems.energy_consumption..tbtu
# calc.weighted.natural_gas.cooling.energy_consumption..tbtu
# calc.weighted.natural_gas.heating.energy_consumption..tbtu
# calc.weighted.natural_gas.interior_equipment.energy_consumption..tbtu
# calc.weighted.natural_gas.total.energy_consumption..tbtu
# calc.weighted.natural_gas.water_systems.energy_consumption..tbtu
# calc.weighted.other_fuel.cooling.energy_consumption..tbtu
# calc.weighted.other_fuel.heating.energy_consumption..tbtu
# calc.weighted.other_fuel.interior_equipment.energy_consumption..tbtu
# calc.weighted.other_fuel.total.energy_consumption..tbtu
# calc.weighted.other_fuel.water_systems.energy_consumption..tbtu
# calc.weighted.savings.district_cooling.cooling.energy_consumption..tbtu
# calc.weighted.savings.district_cooling.total.energy_consumption..tbtu
# calc.weighted.savings.district_heating.cooling.energy_consumption..tbtu
# calc.weighted.savings.district_heating.heating.energy_consumption..tbtu
# calc.weighted.savings.district_heating.total.energy_consumption..tbtu
# calc.weighted.savings.district_heating.water_systems.energy_consumption..tbtu
# calc.weighted.savings.electricity.cooling.energy_consumption..tbtu
# calc.weighted.savings.electricity.exterior_lighting.energy_consumption..tbtu
# calc.weighted.savings.electricity.fans.energy_consumption..tbtu
# calc.weighted.savings.electricity.heat_recovery.energy_consumption..tbtu
# calc.weighted.savings.electricity.heat_rejection.energy_consumption..tbtu
# calc.weighted.savings.electricity.heating.energy_consumption..tbtu
# calc.weighted.savings.electricity.interior_equipment.energy_consumption..tbtu
# calc.weighted.savings.electricity.interior_lighting.energy_consumption..tbtu
# calc.weighted.savings.electricity.pumps.energy_consumption..tbtu
# calc.weighted.savings.electricity.refrigeration.energy_consumption..tbtu
# calc.weighted.savings.electricity.total.energy_consumption..tbtu
# calc.weighted.savings.electricity.water_systems.energy_consumption..tbtu
# calc.weighted.savings.natural_gas.cooling.energy_consumption..tbtu
# calc.weighted.savings.natural_gas.heating.energy_consumption..tbtu
# calc.weighted.savings.natural_gas.interior_equipment.energy_consumption..tbtu
# calc.weighted.savings.natural_gas.total.energy_consumption..tbtu
# calc.weighted.savings.natural_gas.water_systems.energy_consumption..tbtu
# calc.weighted.savings.other_fuel.cooling.energy_consumption..tbtu
# calc.weighted.savings.other_fuel.heating.energy_consumption..tbtu
# calc.weighted.savings.other_fuel.interior_equipment.energy_consumption..tbtu
# calc.weighted.savings.other_fuel.total.energy_consumption..tbtu
# calc.weighted.savings.other_fuel.water_systems.energy_consumption..tbtu
# calc.weighted.savings.site_energy.total.energy_consumption..tbtu
# calc.weighted.site_energy.total.energy_consumption..tbtu

# %%
# List of unique state names (will be important later)
unique_states = list(set(df['in.state'].tolist()))
    
print(unique_states)
# Out:
# ['NH', 'IN', 'NM', 'CA', 'GA', 'IL', 'MT', 'NE', 'AL', 'WI', 'IA', 'AR', 'AK', 'MD', 'NJ', 'VA', 'MO', 'CO', 'NV', 'SD', 'WV', 'NC', 'FL', 'TN', 'ID', 'MS', 'MI', 'NY', 'VT', 'OR', 'HI', 'KY', 'OH', 'UT', 'DE', 'MA', 'KS', 'RI', 'WA', 'LA', 'ND', 'AZ', 'OK', 'MN', 'TX', 'SC', 'PA', 'WY', 'ME', 'DC', 'CT']

# %%
# Create new folders for each state (plus weather)

bidx, state_name = df.index.tolist(), df['in.state'].tolist()
# We convert each into a dictionary, grouped by state name
grouped_by_state = {}
for a,b in zip(bidx,state_name):
    if b not in grouped_by_state:
        grouped_by_state[b] = []
    grouped_by_state[b].append(a)
    
# We now create an empty folder for each state and place a file called links.txt in each which contains the S3 prefix of the relevant files to be downloaded.
for key, value in grouped_by_state.items():
    os.makedirs(base_path+'/'+key, exist_ok = True)
    # populate the download list
    dlist = [f'nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/timeseries_individual_buildings/by_state/upgrade={update_version}/state={key}/{v}-{update_version}.parquet'
            for v in value]
    with open(base_path+'/'+key+'/links.txt', 'w') as file:
        for line in dlist:
            file.write(line + '\n')
            
# We now create an empty folder called weather where we load the weather files
pumas = list(set(df['in.nhgis_county_gisjoin'].tolist()))
os.makedirs(base_path+'/weather', exist_ok = True)
dlist = [f'nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/comstock_amy2018_release_1/weather/amy2018/{p}_2018.csv' for p in pumas]
with open(base_path+'/weather/links.txt', 'w') as file:
    for line in dlist:
        file.write(line + '\n')
